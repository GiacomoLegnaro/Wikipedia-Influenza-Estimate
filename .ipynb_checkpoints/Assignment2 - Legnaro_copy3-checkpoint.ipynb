# %% [markdown]
# <center>
# <hr>
# <h1>Digital Epidemiology</h1>
# <h2>Assignment No. 2 - Influenza-like Illness</h2>
# <h2>Giacomo Legnaro</h2>
# <hr>
# </center>

# %% [markdown]
# The goal of this assignment is to try and reproduce for Italy
# the results reported in the article for the USA *D.J. McIver & J. S. Brownstein (2014), "Wikipedia Usage Estimates Prevalence of Influenza-Like Illness in the United States in Near Real-Time", PLoS Comput Biol 10(4):	http://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1003581*

# %% [markdown]
# Official data on influenza in Italy are collected by the "Istituto Superiore di Sanità" with a program called "Influnet" that uses sentinel doctors.
# The project is described here: http://www.iss.it/iflu/index.php?lang=1&anno=2016&tipo=4
#
# These data will be our ground truth.

# %% [markdown]
# To reproduce the paper we download page view counts from wikipedia of such keywords related to flu.

# %% [markdown]
# Let's start with import all the libraries needed.

# %%
import os
import io
import sys
import glob
import time
import gzip
import shutil
import urllib
import urllib2
import os.path
import datetime
import requests
import cStringIO
import cleanfile
import itertools
import subprocess
import multiprocessing

import scipy.stats
import scipy.signal
import statsmodels.tsa

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scikits.statsmodels.api as sm
import statsmodels.tsa.stattools

from scipy import stats
from sklearn import metrics
from itertools import islice
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from scipy.stats.stats import pearsonr
from sklearn.model_selection import KFold
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import f_regression, mutual_info_regression

from random import choice
from bs4 import BeautifulSoup
from joblib import Parallel, delayed
from multiprocessing.dummy import Pool

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
io_method = cStringIO.StringIO

# %% [markdown]
# # Section 1
#
# ### Wikipedia download data

# %% [markdown]
# First part of this assignment is dedicated to downloads the data from Wikipedia. I have decided to download locally all the data that i'm interested to and only after process them. In this notebook the output of this part will not be full but only a initial printout. All the data are downloaded and analyze with this code.
# (You can run it only modifying the  path. Storage size requested to download all the data locally ~3TB, fibre connection DL:70Mb/s UL:20Mb/s, data download speed 50-65Mb/s)

# %% [markdown]
# #### Limit in download speed and simultaneously number of download files
# One of the problem that I have encounter with the download of the data from https://dumps.wikimedia.org is due to a limited file download speed give from wikimedia and a limit of 3 simultaneously download for each browser. To bypass this limits, I have written the code so that the downloads are parallelized with the use of different "browser" only with send a different *user-agent* string. The number of file download simultaneously for each browser are limited at 2 times number of browser because map function not apply the function in a certain order but randomly, and the mod mode to assign the user-agent string is not so efficient in this case.
# In case of more than 3 file use the same browser, the downloads of the extra file will be interrupt at the begin and the size of this file will be equal to '213'. In this case try-catch with a while loop permit to sleep 2-seconds and retry to download.

# %% [markdown]
# #### Issue with external HD
# Download all the files locally require a lot of large transfers and is not possible to use directly an external HD (I have tried it and it go slowly, with error, and reduce a lot the speed). So, I have download every month in my pc and also after that I have transfer all the files in the external HD.

# %% [markdown]
# #### Wikimedia empty files
# One other problem is the presence of empty file, this case are treated separately with relax of some constraint impose in the rest of the downloads.

# %% [markdown]
# #### Wikimedia raw data
# From 2015-05 Wikimedia datasets is getting produced by stripping down extra-information from Pagecounts-all-sites.
# This required a change in the path from pagecounts-raw up to 2015-04 to pageviews from 2015-05.

# %% [markdown]
# #### Data collected
# The data collected are from 2011-10-01 up to 2016-04-30: 5 Influenza seasons.

# %%
def makeDirectory(path):
    """
    Return the directory path where save the documents

    :param path: path where create the new folder
    :param directory: name of the new folder
    """
    try:
        os.makedirs(os.path.join(path))
    except OSError:
        if not os.path.isdir(os.path.join(path)):
            raise
    return os.path.join(path)

# %%
def download_data(yr,mth,l_dl):
    path = yr + '/' + mth + '/' + l_dl
    urllib.URLopener.version = user_agents[link_dl.index(l_dl)%len(user_agents)]
    wikimedia = urllib.URLopener() 
    headers = {"Content-Length": '213'}
    while int(headers["Content-Length"]) < 5000: 
        try:
            filename, headers = wikimedia.retrieve(main_url + path, '/Users/giacomolegnaro/Downloads/Wikimedia/' + l_dl)
        except IOError:
            time.sleep(2)
    print(yr + ' ' + mth + ' ' + l_dl + ' - Progress ' + str(round(float(len(os.listdir('/Users/giacomolegnaro/Downloads/Wikimedia/'))) / len(link_dl)*100, 2))+'%')

# %%
opener = urllib2.build_opener()

# %%
user_agents = [
    'AmigaVoyager/3.2 (AmigaOS/MC680x0)',
    'Cyberdog/2.0 (Macintosh; PPC)',
    'IBM WebExplorer /v0.94',
    'Lynx/2.8.5rel.1 libwww-FM/2.14 SSL-MM/1.4.1 GNUTLS/1.2.9',
    'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)',
    'Mozilla/4.0 (compatible; MSIE 7.0; America Online Browser 1.1; Windows NT 5.1; (R1 1.5); .NET CLR 2.0.50727; InfoPath.1)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0; .NET4.0C; .NET4.0E; .NET CLR 2.0.50727; .NET CLR 1.1.4322; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; Browzar)',
    'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; WOW64; Trident/4.0; Deepnet Explorer 1.5.3; Smart 2x2; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; Avant Browser; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)',
    'Mozilla/4.08 (Charon; Inferno)',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/7046A194A',
    'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.6; en-US; rv:1.9.2.3) Gecko/20100402 Prism/1.0b4',
    'Mozilla/5.0 (Macintosh; U; PPC Mac OS X Mach-O; XH; rv:8.578.498) fr, Gecko/20121021 Camino/8.723+ (Firefox compatible)',
    'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; en) AppleWebKit/418.8 (KHTML, like Gecko, Safari) Cheshire/1.0.UNOFFICIAL',
    'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; pl-PL; rv:1.0.1) Gecko/20021111 Chimera/0.6',
    'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; pl-pl) AppleWebKit/312.8 (KHTML, like Gecko, Safari) DeskBrowse/1.0',
    'Mozilla/5.0 (Macintosh; U; PPC; en-US; mimic; rv:9.3.0) Gecko/20120117 Firefox/3.6.25 Classilla/CFM',
    'Mozilla/5.0 (Windows NT 5.2; RW; rv:7.0a1) Gecko/20091211 SeaMonkey/9.23a1pre',
    'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/534.24 (KHTML, like Gecko) RockMelt/0.9.58.494 Chrome/11.0.696.71 Safari/534.24',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; AS; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/535.7 (KHTML, like Gecko) Comodo_Dragon/16.1.1.0 Chrome/16.0.912.63 Safari/535.7',
    'Mozilla/5.0 (Windows; U; Win 9x 4.90; SG; rv:1.9.2.4) Gecko/20101104 Netscape/9.1.0285',
    'Mozilla/5.0 (Windows; U; WinNT; en; rv:1.0.2) Gecko/20030311 Beonex/0.8.2-stable',
    'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.2 (KHTML, like Gecko) ChromePlus/4.0.222.3 Chrome/4.0.222.3 Safari/532.2',
    'Mozilla/5.0 (Windows; U; Windows NT 5.1; it; rv:1.8.1.11) Gecko/20071127 Firefox/2.0.0.11',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.3) Gecko/20100409 Firefox/3.6.3 CometBird/3.6.3',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13',
    'Mozilla/5.0 (X11; Linux x86_64; rv:10.0.11) Gecko/20100101 conkeror/1.0pre (Debian-1.0~~pre+git120527-1)',
    'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.3a) Gecko/20021207 Phoenix/0.5',
    'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.0.12) Gecko/20070731 Ubuntu/dapper-security Firefox/1.5.0.12',
    'Mozilla/5.0 (X11; U; Linux i686; nl; rv:1.8.1b2) Gecko/20060821 BonEcho/2.0b2 (Debian-1.99+2.0b2+dfsg-1)',
    'Mozilla/5.0 (X11; U; Linux x86_64; cs-CZ) AppleWebKit/533.3 (KHTML, like Gecko) rekonq Safari/533.3',
    'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.5 (like Gecko) (Kubuntu)',
    'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; SV1; Crazy Browser 9.0.04)',
    'Mozilla/5.0 (compatible; MSIE 9.0; AOL 9.7; AOLBuild 4343.19; Windows NT 6.1; WOW64; Trident/5.0; FunWebProducts)',
    'Mozilla/5.0 (compatible; U; ABrowse 0.6; Syllable) AppleWebKit/420+ (KHTML, like Gecko)Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; Acoo Browser 1.98.744; .NET CLR 3.5.30729)',
    'Mozilla/6.0 (X11; U; Linux x86_64; en-US; rv:2.9.0.3) Gecko/2009022510 FreeBSD/ Sunrise/4.0.1/like Safari',
    'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16',
    'Sundance/0.9x(Compatible; Windows; U; en-US;)Version/0.9x'
]

# %%
for yr in ['2016']:
    for m in ['-04','-03','-02','-01']:
        mth = yr + m

        if (yr == '2016') or ((yr == '2015') and (m not in ['-01', '-02', '-03', '-04'])):
            sel = 'pageviews'
        else:
            sel = 'pagecounts-raw'
        main_url = 'https://dumps.wikimedia.org/other/' + sel + '/'
        print(yr + ' ' + mth)
        r = requests.get(main_url + yr + '/' + mth + '/')
        soup = BeautifulSoup(r.content, "html.parser")
        link_dl = [link.get('href').encode('utf8') for link in soup.find_all('a') if ((link.get('href') == link.string) and (link.string.split('-')[0] == sel.split('-')[0]))]
        print len(link_dl)
        makeDirectory('/Users/giacomolegnaro/Downloads/Wikimedia/')
        makeDirectory('/Volumes/My Book/Wikimedia/' + sel + '/' + yr + '/' + mth + '/')

        p = Pool(len(user_agents)*2)

        out = p.map(lambda l_dl: download_data(yr,mth,l_dl), link_dl)

        path = yr + '/' + mth + '/'
        source = '/Users/giacomolegnaro/Downloads/Wikimedia/'
        dest = '/Volumes/My Book/Wikimedia/' + sel + '/'
        out = [shutil.move(source + f,dest + path + f) for f in os.listdir(source)]

# %%
for yr in ['2015','2014','2013','2012']:
    for m in ['-12','-11','-10','-04','-03','-02','-01']:
        mth = yr + m

        if (yr == '2016') or ((yr == '2015') and (m not in ['-01', '-02', '-03', '-04'])):
            sel = 'pageviews'
        else:
            sel = 'pagecounts-raw'
        main_url = 'https://dumps.wikimedia.org/other/' + sel + '/'
        print(yr + ' ' + mth)
        r = requests.get(main_url + yr + '/' + mth + '/')
        soup = BeautifulSoup(r.content, "html.parser")
        link_dl = [link.get('href').encode('utf8') for link in soup.find_all('a') if ((link.get('href') == link.string) and (link.string.split('-')[0] == sel.split('-')[0]))]
        print len(link_dl)
        makeDirectory('/Users/giacomolegnaro/Downloads/Wikimedia/')
        makeDirectory('/Volumes/My Book/Wikimedia/' + sel + '/' + yr + '/' + mth + '/')

        p = Pool(len(user_agents)*2)

        out = p.map(lambda l_dl: download_data(yr,mth,l_dl), link_dl)

        path = yr + '/' + mth + '/'
        source = '/Users/giacomolegnaro/Downloads/Wikimedia/'
        dest = '/Volumes/My Book/Wikimedia/' + sel + '/'
        out = [shutil.move(source + f,dest + path + f) for f in os.listdir(source)]

# %%
for yr in ['2011']:
    for m in ['-12','-11','-10']:
        mth = yr + m

        if (yr == '2016') or ((yr == '2015') and (m not in ['-01', '-02', '-03', '-04'])):
            sel = 'pageviews'
        else:
            sel = 'pagecounts-raw'
        main_url = 'https://dumps.wikimedia.org/other/' + sel + '/'
        print(yr + ' ' + mth)
        r = requests.get(main_url + yr + '/' + mth + '/')
        soup = BeautifulSoup(r.content, "html.parser")
        link_dl = [link.get('href').encode('utf8') for link in soup.find_all('a') if ((link.get('href') == link.string) and (link.string.split('-')[0] == sel.split('-')[0]))]
        print len(link_dl)
        makeDirectory('/Users/giacomolegnaro/Downloads/Wikimedia/')
        makeDirectory('/Volumes/My Book/Wikimedia/' + sel + '/' + yr + '/' + mth + '/')

        p = Pool(len(user_agents)*2)

        out = p.map(lambda l_dl: download_data(yr,mth,l_dl), link_dl)

        path = yr + '/' + mth + '/'
        source = '/Users/giacomolegnaro/Downloads/Wikimedia/'
        dest = '/Volumes/My Book/Wikimedia/' + sel + '/'
        out = [shutil.move(source + f,dest + path + f) for f in os.listdir(source)]

# %% [markdown]
# #### Code to download not ok files (interrupt, error not try-catch, exceptions)
# This code is used  4-5 times in all the download time

# %%
yr = '2011'
m = '-12'
mth = yr + m

# %%
if (yr == '2016') or ((yr == '2015') and (m not in ['-01', '-02', '-03', '-04'])):
    sel = 'pageviews'
else:
    sel = 'pagecounts-raw'
main_url = 'https://dumps.wikimedia.org/other/' + sel + '/'

# %%
print(yr + ' ' + mth)
r = requests.get(main_url + yr + '/' + mth + '/')
soup = BeautifulSoup(r.content, "html.parser")
link_dl = [link.get('href').encode('utf8') for link in soup.find_all('a') if ((link.get('href') == link.string) and (link.string.split('-')[0] == sel.split('-')[0]))]
file_dl = os.listdir('/Users/giacomolegnaro/Downloads/Wikimedia/')
# make the difference between downloaded files and not downloaded
to_dl = list(set(link_dl) - set(file_dl))
to_dl

# %%
def download_data(yr,mth,l_dl):
    path = yr + '/' + mth + '/' + l_dl
    urllib.URLopener.version = user_agents[link_dl.index(l_dl)%len(user_agents)]
    wikimedia = urllib.URLopener() 
    wikimedia.retrieve(main_url + path, '/Users/giacomolegnaro/Downloads/Wikimedia/' + l_dl)
    print(yr + ' ' + mth + ' ' + l_dl + ' - Progress ' + str(round(float(len(os.listdir('/Users/giacomolegnaro/Downloads/Wikimedia/'))) / len(link_dl)*100, 2))+'%')

# %%
for l_dl in to_dl:
    download_data(yr,mth,l_dl)

# %%
path = yr + '/' + mth + '/'
source = '/Users/giacomolegnaro/Downloads/Wikimedia/'
dest = '/Volumes/My Book/Wikimedia/' + sel + '/'
out = [shutil.move(source + f,dest + path + f) for f in os.listdir(source)]

# %% [markdown]
# # Section 2
#
# ### Wikipedia analyze data

# %% [markdown]
# Second part of this notebook is dedicated to the analyze of the download files. Each month required to comment the row code free and uncomment the desired month.
#
# (The code is reported in one chunck - mainly algorithm - and is request to comment/uncomment only PATH_TO_FILE for each month)

# %% [markdown]
# *Note: This code work only with macOS system. The 'gzcat' function to ungzip the file request masOS Operating System.*

# %% [markdown]
# #### Slow analyze
# One of the limit in the speed of the analyze is due to the read speed from an external HD (USB 3.0) but in this case nothing is possible to reduce it.
#
# Ungzip the file and read row by row required ~30 seconds for each file, too much!
# With 'gzcat' function I have reduce a lot the time to unzip (~1-2 seconds).
#
# Another limit is due to read all the rows of the file! This is not necessary! I have open and read some random files and I have seen thata it start always after 3500000 rows, and with the function islice from itertools I have reduce a lot the computational time.
# Similarly to the jump at 3500000 I have think is not necessary to read all the rows after, and when 'it' is no more the row start, I have dropped down the analyze and go to the next file.
#
# At the end, the time for each file go from 2 to 5 seconds.

# %% [markdown]
# #### 'it' and 'it.m'
# I have read in the wikimedia page https://dumps.wikimedia.org/other/pagecounts-raw/, open and read some random files and I have found that 'it.m' is not the page views from mobile devices but of wikimedia project. 'it.mw' is the correct views from the wikipedia mobile devices, but this views are not for each page, but aggregated! In this study I have only considered the 'it' page views.

# %% [markdown]
# #### Chronology wikipedia pages
# Yes, another problem!
# Sometimes the page are subject to a merge with other pages, or to a change of the name, or some other things.
# I assume are not all, but I will report below some things:
#  - 13:53, 6 dic 2013 "Gambo7 ha spostato la pagina Virus dell'influenza A sottotipo H1N1 a Influenzavirus A sottotipo H1N1: omologia con Influenzavirus A". In this case an user have changed and merge *Virus_dell'influenza_A_sottotipo_H1N1* into *Influenzavirus_A_sottotipo_H1N1* due to a homology with *Influenzavirus_A*
#  - *Virus_dell'influenza_A_sottotipo_H1N1* vs *Virus_dell%27influenza_A_sottotipo_H1N1* issue with the superscript character "'"
#  -  19:56, 7 nov 2011 "Doc.mari ha spostato Vaccino influenzale a Vaccino antinfluenzale". In this case the user have changed the name from *Vaccino_influenzale* to *Vaccino_antinfluenzale*. I have seen this things too late. The series is affected by this anomaly at the beginning
#
# Another things about wikipedia keywords search: '#' indicate the section in a page, but the data available reported only the total page and not the single section.
# (e.g. Vaccino_antinfluenzale#Vaccino_influenza_stagionale)

# %% [markdown]
# #### Wikipedia pages related to flu
# Symptom:
#  - Artralgia
#  - Cefalea
#  - Febbre
#  - Fotofobia
#  - Mialgia
#  - Raffreddore_comune
#  - Rinorrea
#  - Starnuto
#  - Tosse
#  - Vomito
#
# Pharmaceutical drug:
#  - Amantadina
#  - Antivirale
#  - Paracetamolo
#  - Oseltamivir
#  - Zanamivir
#
# Flu vaccines:
#  - Vaccino_antinfluenzale
#
# Flu type:
#  - Influenza_aviaria
#  - Influenza
#  - Influenzavirus_A_sottotipo_H1N1
#  - Influenzavirus_A
#  - Virus_dell'influenza_A_sottotipo_H1N1
#  - Virus_dell%27influenza_A_sottotipo_H1N1
#
# Institution:
#  - Centro_europeo_per_la_prevenzione_e_il_controllo_delle_malattie
#  - Istituto_superiore_di_sanità
#
# General keywords related (fear)
#  - Epidemia
#  - Pandemia_influenzale

# %% [markdown]
# #### Analyze data
# The keyword list above are searched in each file; when they are founded,  they have the number of views in the third column. I have created a file for each keywords and at each occur I update the files with the date in format YYYYMMDDHHMMSS follow by the page views value (third column in each row of the gzip file) and a '\n' character.
#
# An extra file I have created to saved all the page views in Italy: 'totalViews'.

# %%
keywords = [
    "Amantadina",
    "Antivirale",
    "Artralgia",
    "Cefalea",
    "Centro_europeo_per_la_prevenzione_e_il_controllo_delle_malattie",
    "Epidemia",
    "Febbre",
    "Fotofobia",
    "Influenza_aviaria",
    "Influenza",
    "Influenzavirus_A_sottotipo_H1N1",
    "Influenzavirus_A",
    "Istituto_superiore_di_sanità",
    "Mialgia",
    "Oseltamivir",
    "Pandemia_influenzale",
    "Paracetamolo",
    "Raffreddore_comune",
    "Rinorrea",
    "Starnuto",
    "Tosse",
    "Vaccino_antinfluenzale",
    "Virus_dell'influenza_A_sottotipo_H1N1",
    "Virus_dell%27influenza_A_sottotipo_H1N1",
    "Vomito",
    "Zanamivir"
]

# %%
PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pagecounts-raw/2011'
# PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pagecounts-raw/2012'
# PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pagecounts-raw/2013'
# PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pagecounts-raw/2014'
# PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pagecounts-raw/2015'
# PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pageviews/2015'
# PATH_TO_FILE = '/Volumes/My Book/Wikimedia/pageviews/2016'
FILE_DIR = '/Users/giacomolegnaro/Documents/Data Science/2nd Year/Digital Epidemiology/Homework2/Wikimedia/clean'

# %%
for dirname, dirnames, filenames in os.walk(PATH_TO_FILE):
    for subdirname in dirnames:
        print subdirname
        for gzip_path in glob.glob(os.path.join(dirname, subdirname) + "/*.gz"):
            fileName = gzip_path.split('/')[-1][:-3].split('-')
            print gzip_path.split('/')[-1][:-3]
            if os.path.isdir(gzip_path) == False:
                p = subprocess.Popen(['gzcat', gzip_path], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
                fh = io_method(p.communicate()[0])
                assert p.returncode == 0
                ct = 0
                for line in islice(fh, 3500000, None):
                    lineList = line.split(' ')
                    if lineList[0] == 'it':
                        try:
                            ct += int(lineList[2])
                        except IndexError:
                            ct += 0
                        if lineList[1] in keywords:
                            with open(FILE_DIR + '/' + lineList[1] + '.txt', 'a') as output:
                                output.write(fileName[1] + fileName[2] + ' ' + lineList[2] + '\n')
                    elif ((lineList[0] != 'it') and (ct != 0)):
                        break
                
                with open (FILE_DIR + '/' 'totalViews.txt','a') as output:
                    output.write(fileName[1] + fileName[2] + ' ' + str(ct) + '\n')

# %% [markdown]
# # Section 3

# %% [markdown]
# ## Process official data on "Influenza" in Italy
# ### Data from Influnet surveillance system

# %% [markdown]
# Influnet series collect data for each year from mid October to mid-April. The file contains a lot of information, too much for us! We consider only the first column Year-Week (YYYY-WW) [ISO_week_date] and the fifth column with the estimated flu incidence for that week.

# %% [markdown]
# Issue:
# The data are with separator character a *blank* ' ', thousands character *dot* '.' and *comma* as decimal ','.
#
# This assumption is not true only in the 2013-2014 season. In this case the thousands character and decimal are invert!
# With a delete of the series and a new loading with this precaution all is ok.

# %%
path_gt = 'influnet/data/'
path = 'Wikimedia/clean/'

# %%
gt_ts = pd.concat([pd.read_csv(f, sep=' ', thousands='.', decimal=',', index_col=0, skiprows = 1, usecols=[0,4], names = ['time',f.split('_')[1].split('.')[0]]) for f in glob.glob(path_gt + "/*.txt")], axis=1)

# %%
del gt_ts['2013-2014']

# %%
f = path_gt + "influnet_2013-2014.txt"
gt_ts = pd.concat([gt_ts, pd.read_csv(f, sep=' ', thousands=',', decimal='.', index_col=0, skiprows = 2, usecols=[0,4], names = ['time',f.split('_')[1].split('.')[0]])], axis=1).sum(axis=1)
gt_ts = gt_ts.fillna(0)
gt_ts_raw = gt_ts.copy()

# %% [markdown]
# Plot all the official series, only to a briefly view

# %%
gt_ts.plot(legend=True, label='Groud Truth')
plt.title('Official Data On Influenza In Italy ['+ min(gt_ts.index)+' - '+max(gt_ts.index)+']', fontsize=14)
plt.xlabel('Year-Week')
plt.ylabel('Estimated flu incidence')
plt.grid()
plt.show()

# %% [markdown]
# The period consider start from the 42th week's of 2011 and we reduce the ground truth series to this period.

# %%
init_date = '2011-42'
gt_ts = gt_ts[init_date:]

# %%
gt_ts.plot(legend=True, label='Groud Truth')
plt.title('Official Data On Influenza In Italy ['+ min(gt_ts.index)+' - '+max(gt_ts.index)+']', fontsize=14)
plt.xlabel('Year-Week')
plt.ylabel('Estimated flu incidence')
plt.grid()
plt.show()

# %% [markdown]
# ## Part 1.1
#
# ### Process the Wikipedia pageview data for the "Influenza" page of the Italian

# %% [markdown]
# Define a function to aggregate the pageviews on a weekly time scale. function strftime works on macOS an with the string "%G-%V" take the datetime and return the Year and Week in ISO calendar (the week start on Monday and the week beetween two years belong to the year with majority of its day - thursday is the tip of the balance)

# %%
def hourlyToWeekly(filename, sep):
    ts = pd.Series.from_csv(filename, sep = sep, header=None, index_col = 0)
    wts = ts.groupby(ts.index.strftime("%G-%V")).sum()
    return wts

# %%
df = pd.concat([hourlyToWeekly(f, ' ') for f in glob.glob(path + "/*.txt")], axis=1)
df = df.fillna(0)

df.columns = [os.path.basename(f).split('.')[0] for f in glob.glob(path + "/*.txt")]

# %%
df["Influenzavirus_A_sottotipo_H1N1"] = df["Influenzavirus_A_sottotipo_H1N1"].add(df["Virus_dell'influenza_A_sottotipo_H1N1"], fill_value=0).add(df["Virus_dell%27influenza_A_sottotipo_H1N1"], fill_value=0)

del df["Virus_dell'influenza_A_sottotipo_H1N1"]
del df["Virus_dell%27influenza_A_sottotipo_H1N1"]

# %% [markdown]
# As explained in section 2 we merge the three series:
#  - *Influenzavirus_A_sottotipo_H1N1*
#  - *Virus_dell'influenza_A_sottotipo_H1N1*
#  - *Virus_dell%27influenza_A_sottotipo_H1N1*
# and delete the extra

# %%
df_raw = df.copy()
df_raw
# Out:
#          Amantadina  Antivirale  Artralgia  Cefalea  \
# 2011-39          43          55         93      395
# 2011-40         155         164        366     1582
# 2011-41         155         174        396     1604
# 2011-42         162         178        391     1526
# 2011-43         183         210        385     1696
# 2011-44         224         279        449     2074
# 2011-45         221         248        466     2306
# 2011-46         290         245        464     2009
# 2011-47         252         297        437     2200
# 2011-48         243         280        462     2037
# 2011-49         185         230        439     1880
# 2011-50         252         295        425     1937
# 2011-51         124         150        213      902
# 2011-52         156         202        285     1317
# 2012-01         236         307        455     1861
# 2012-02         335         329        478     2062
# 2012-03         313         282        455     1864
# 2012-04         300         296        539     2102
# 2012-05         312         342        532     1995
# 2012-06         347         381        607     1963
# 2012-07         327         366        564     1918
# 2012-08         315         340        716     2079
# 2012-09         236         309        538     2134
# 2012-10         245         259        543     1652
# 2012-11         178         278        579     1974
# 2012-12         166         255        516     1767
# 2012-13         178         291        625     1750
# 2012-14         213         244        514     1632
# 2012-15         198         267        544     1751
# 2012-16         220         275        617     1900
# ...             ...         ...        ...      ...
# 2015-41         109         104        459      755
# 2015-42          99         150        299      663
# 2015-43         123         115        208      684
# 2015-44         127         105        253      648
# 2015-45         119         117        249      744
# 2015-46         156         107        222      718
# 2015-47         137         242        199      635
# 2015-48         145         117        218      687
# 2015-49         134         129        206      625
# 2015-50         133         111        202      636
# 2015-51         141         130        211      576
# 2015-52          65         110        132      395
# 2015-53         107         106        168      517
# 2016-01         128         126        226      591
# 2016-02         157         160        271      670
# 2016-03         194         164        266      744
# 2016-04         185         158        310      795
# 2016-05         177         165        312      871
# 2016-06         188         178        278      827
# 2016-07         222         163        297      806
# 2016-08         165         181        309      761
# 2016-09         136         154        269      774
# 2016-10         129         170        259      804
# 2016-11         155         136        263      717
# 2016-12         125         157        202      665
# 2016-13         118         127        249      652
# 2016-14         106         152        249      708
# 2016-15         105         132        261      723
# 2016-16         136         164        258      615
# 2016-17         132         116        214      560
#
#          Centro_europeo_per_la_prevenzione_e_il_controllo_delle_malattie  \
# 2011-39                                                  5
# 2011-40                                                 28
# 2011-41                                                 24
# 2011-42                                                 51
# 2011-43                                                 34
# 2011-44                                                 27
# 2011-45                                                 24
# 2011-46                                                 39
# 2011-47                                                 32
# 2011-48                                                 27
# 2011-49                                                 22
# 2011-50                                                 26
# 2011-51                                                 16
# 2011-52                                                 18
# 2012-01                                                 27
# 2012-02                                                 24
# 2012-03                                                 23
# 2012-04                                                 26
# 2012-05                                                 24
# 2012-06                                                 24
# 2012-07                                                 22
# 2012-08                                                 25
# 2012-09                                                 27
# 2012-10                                                 27
# 2012-11                                                 22
# 2012-12                                                 24
# 2012-13                                                 23
# 2012-14                                                 27
# 2012-15                                                 58
# 2012-16                                                 27
# ...                                                    ...
# 2015-41                                                 25
# 2015-42                                                 28
# 2015-43                                                 19
# 2015-44                                                 14
# 2015-45                                                 27
# 2015-46                                                 17
# 2015-47                                                 14
# 2015-48                                                 23
# 2015-49                                                 17
# 2015-50                                                 25
# 2015-51                                                 23
# 2015-52                                                 17
# 2015-53                                                 18
# 2016-01                                                 45
# 2016-02                                                 23
# 2016-03                                                 17
# 2016-04                                                 20
# 2016-05                                                 19
# 2016-06                                                 25
# 2016-07                                                 17
# 2016-08                                                 16
# 2016-09                                                 28
# 2016-10                                                 17
# 2016-11                                                 27
# 2016-12                                                 19
# 2016-13                                                 19
# 2016-14                                                 26
# 2016-15                                                 29
# 2016-16                                                 25
# 2016-17                                                 13
#
#          Epidemia  Febbre  Fotofobia  Influenza  Influenza_aviaria    ...      \
# 2011-39       120    1054        108        244                101    ...
# 2011-40       355    3686        354       1083                326    ...
# 2011-41       370    3502        386       1101                307    ...
# 2011-42       378    3499        433       1176                276    ...
# 2011-43       413    3696        463       1119                354    ...
# 2011-44       433    3962        527       1309                298    ...
# 2011-45       425    4158        616       1352                343    ...
# 2011-46       450    4139        508       1420                371    ...
# 2011-47       440    4367        576       1558                414    ...
# 2011-48       552    4403        506       1534               1470    ...
# 2011-49       439    4161        469       1387                478    ...
# 2011-50       422    4339        499       1463                438    ...
# 2011-51       234    2471        268        833                747    ...
# 2011-52       263    4882        375       1588                604    ...
# 2012-01       535    5952        528       2037                466    ...
# 2012-02       513    5885        645       2083                525    ...
# 2012-03       463    6320        487       2092                527    ...
# 2012-04       550    6978        536       2507                527    ...
# 2012-05       506    7657        483       2728                519    ...
# 2012-06       505    7196        568       2282                492    ...
# 2012-07       509    6971        551       2198                483    ...
# 2012-08       495    7253        596       2237                446    ...
# 2012-09       422    5741        556       1664                430    ...
# 2012-10       398    5100        552       1161                458    ...
# 2012-11       538    4163        624       1198                435    ...
# 2012-12       418    3828        553        938                356    ...
# 2012-13       426    3295        580       1019                368    ...
# 2012-14       415    3116        480        782                372    ...
# 2012-15       468    3283        547        811                385    ...
# 2012-16       460    3952        588        872                390    ...
# ...           ...     ...        ...        ...                ...    ...
# 2015-41       277     861        354        642                202    ...
# 2015-42       194     892        204        530                175    ...
# 2015-43       229     895        204        507                183    ...
# 2015-44       220     825        200        479                300    ...
# 2015-45       274     847        200        576                198    ...
# 2015-46       217     832        202        549                180    ...
# 2015-47       210     909        236        532                181    ...
# 2015-48       214     957        212        570                215    ...
# 2015-49       187     924        175        563                307    ...
# 2015-50       165     970        177        525                197    ...
# 2015-51       167     881        163        580                137    ...
# 2015-52        96     661        145        422                 91    ...
# 2015-53       157     899        139        525                227    ...
# 2016-01       199    1155        187        660                197    ...
# 2016-02       244    1133        244        753                297    ...
# 2016-03       264    1086        219        751                212    ...
# 2016-04       291    1284        230        702                264    ...
# 2016-05       290    1510        219        793                260    ...
# 2016-06       348    1367        297        804                248    ...
# 2016-07       784    1421        275        776                298    ...
# 2016-08       467    1421        214        778                241    ...
# 2016-09       255    1282        251        676                263    ...
# 2016-10       247    1309        248        691                226    ...
# 2016-11       207    1267        227        757                222    ...
# 2016-12       179    1078        169        637                158    ...
# 2016-13       250    1042        221        777                241    ...
# 2016-14       213     940        222        544                218    ...
# 2016-15       237     936        212        465                190    ...
# 2016-16       182     793        229        467                196    ...
# 2016-17       214     726        168        395                336    ...
#
#          Pandemia_influenzale  Paracetamolo  Raffreddore_comune  Rinorrea  \
# 2011-39                    20          1112                 491        68
# 2011-40                    77          4078                1772       327
# 2011-41                   106          4331                2095       333
# 2011-42                   113          4485                1898       363
# 2011-43                    83          4848                1747       352
# 2011-44                   100          4973                1783       333
# 2011-45                    93          4787                1545       369
# 2011-46                    93          4935                1789       374
# 2011-47                   117          6523                1830       375
# 2011-48                   121          5040                1831       404
# 2011-49                    92          4729                1566       367
# 2011-50                   107          4900                1533       366
# 2011-51                    70          3477                1141       168
# 2011-52                    83          5972                1861       278
# 2012-01                   140          6817                2352       425
# 2012-02                   106          6363                2087       409
# 2012-03                   115          6256                1865       375
# 2012-04                   148          6208                2266       433
# 2012-05                   149          6953                2229       434
# 2012-06                   143          7028                2136       412
# 2012-07                    97          6464                2142       390
# 2012-08                   110          6043                2116       814
# 2012-09                   117          5430                1893       408
# 2012-10                   117          7008                1753       393
# 2012-11                   396          4183                1564       424
# 2012-12                   128          3471                1320       400
# 2012-13                   100          3626                1246       429
# 2012-14                    76          3246                 961       344
# 2012-15                   112          3743                1106       364
# 2012-16                   112          3817                1074       345
# ...                       ...           ...                 ...       ...
# 2015-41                    62          1984                1039       161
# 2015-42                    43          1995                 922       197
# 2015-43                    48          1879                 787       147
# 2015-44                    64          1805                 607       137
# 2015-45                    60          1881                 606       163
# 2015-46                    58          1728                 523       148
# 2015-47                    42          1880                 480       163
# 2015-48                    68          1791                 586       153
# 2015-49                    48          2335                 604       144
# 2015-50                    47          2056                 575       186
# 2015-51                    68          1923                 648       174
# 2015-52                    42          1673                 554       122
# 2015-53                    58          1942                 788       169
# 2016-01                    64          2154                 936       226
# 2016-02                    65          2191                 771       212
# 2016-03                    69          2083                 805       185
# 2016-04                    82          2295                 852       229
# 2016-05                    79          2313                 820       240
# 2016-06                    99          2420                 751       218
# 2016-07                    68          2215                 688       200
# 2016-08                    83          2291                 657       200
# 2016-09                   124          2079                 575       187
# 2016-10                    65          2020                 497       194
# 2016-11                    56          2024                 519       172
# 2016-12                    51          1723                 411       196
# 2016-13                    42          1661                 598       179
# 2016-14                    51          1879                 427       183
# 2016-15                    38          1572                 415       149
# 2016-16                    58          1515                 424       181
# 2016-17                    44          1514                 399       125
#
#          Starnuto  Tosse  totalViews  Vaccino_antinfluenzale  Vomito  \
# 2011-39       153    377    27539912                     0.0     481
# 2011-40       436   1351   118338276                     0.0    1512
# 2011-41       499   1491    94647305                     0.0    1659
# 2011-42       454   1663    93271823                     0.0    1724
# 2011-43       454   1947    99364715                     0.0    1825
# 2011-44       498   2211   108841801                     0.0    2173
# 2011-45       483   2268   109836162                   394.0    2118
# 2011-46       513   2140   106748952                   826.0    2110
# 2011-47       564   2277   105517950                  1129.0    2276
# 2011-48       498   2179   103806835                   761.0    2437
# 2011-49       498   2051   101174357                   453.0    2152
# 2011-50       518   1935   104067037                   345.0    2093
# 2011-51       285   1120    55305462                   147.0    1188
# 2011-52       423   1935    90211318                   160.0    2477
# 2012-01       643   2649   119823036                   179.0    2726
# 2012-02       632   2782   116279474                   197.0    2759
# 2012-03       565   2596   109904116                   187.0    2506
# 2012-04       584   2787   115702289                   199.0    2354
# 2012-05       619   2783   116246769                   238.0    2338
# 2012-06       620   2595   119656983                   190.0    2278
# 2012-07       580   2471   113809247                   188.0    2611
# 2012-08       688   2345   112860742                   174.0    2644
# 2012-09       664   2115   112172874                   169.0    2599
# 2012-10       603   2088   107815827                   120.0    2501
# 2012-11       521   1748   101505308                   134.0    2068
# 2012-12       489   1280    99418248                    90.0    1806
# 2012-13       528   1042    99082137                    80.0    1677
# 2012-14       502    990    97879780                    76.0    1650
# 2012-15       448   1013   107373915                    80.0    1978
# 2012-16       414   1026   106949016                    94.0    2063
# ...           ...    ...         ...                     ...     ...
# 2015-41       207    352    54469589                   188.0     444
# 2015-42       211    348    52542024                   291.0     445
# 2015-43       186    345    49880045                   316.0     416
# 2015-44       182    388    49865506                   273.0     423
# 2015-45       182    360    52650244                   358.0     442
# 2015-46       186    409    53722960                   383.0     485
# 2015-47       156    339    55196890                   413.0     448
# 2015-48       197    308    53103330                   328.0     441
# 2015-49       184    328    51818693                   251.0     429
# 2015-50       214    323    50784272                   156.0     434
# 2015-51       269    326    49134283                   110.0     397
# 2015-52       158    286    41918624                    85.0     298
# 2015-53       182    336    48141667                    62.0     477
# 2016-01       242    395    59225424                    83.0     484
# 2016-02       218    476    60808188                    85.0     555
# 2016-03       269    411    59441516                    95.0     481
# 2016-04       287    388    58728254                    85.0     541
# 2016-05       267    403    59952557                    94.0     530
# 2016-06       268    429    60372242                    77.0     492
# 2016-07       297    443    59536013                    79.0     506
# 2016-08       276    416    57084524                    67.0     473
# 2016-09       227    378    59638966                    40.0     440
# 2016-10       221    391    56797538                    52.0     478
# 2016-11       197    352    56949096                    46.0     441
# 2016-12       207    290    56824960                    48.0     372
# 2016-13       220    272    58237823                    75.0     403
# 2016-14       192    273    53090047                    60.0     394
# 2016-15       208    316    50953039                    41.0     358
# 2016-16       232    256    53964932                    50.0     386
# 2016-17       147    192    46426870                    53.0     338
#
#          Zanamivir
# 2011-39         12
# 2011-40         35
# 2011-41         49
# 2011-42         68
# 2011-43         67
# 2011-44         62
# 2011-45         55
# 2011-46         67
# 2011-47         59
# 2011-48         78
# 2011-49         94
# 2011-50         69
# 2011-51         35
# 2011-52         62
# 2012-01         73
# 2012-02         94
# 2012-03         84
# 2012-04        144
# 2012-05        179
# 2012-06        145
# 2012-07        128
# 2012-08        121
# 2012-09         73
# 2012-10         72
# 2012-11         78
# 2012-12         56
# 2012-13         69
# 2012-14         47
# 2012-15         54
# 2012-16         62
# ...            ...
# 2015-41         24
# 2015-42         21
# 2015-43         18
# 2015-44         23
# 2015-45         31
# 2015-46         38
# 2015-47         35
# 2015-48         29
# 2015-49         22
# 2015-50         69
# 2015-51         39
# 2015-52         20
# 2015-53         32
# 2016-01         32
# 2016-02         37
# 2016-03         40
# 2016-04         47
# 2016-05         48
# 2016-06         41
# 2016-07         42
# 2016-08         29
# 2016-09         30
# 2016-10         32
# 2016-11         43
# 2016-12         26
# 2016-13         23
# 2016-14         43
# 2016-15         28
# 2016-16         25
# 2016-17         18
#
# [156 rows x 25 columns]

# %% [markdown]
# The series are downloaded from the beginning of October to the end of April. But the Influnet series are a subset! To compare the two time series, we exctract a subset from the wikipedia data with indexes given by the ground truth.

# %%
init_date = min(set(df.index) & set(gt_ts.index))
init_date
# Out:
# '2011-42'

# %%
gt_ts = gt_ts[init_date:]

# %%
df = df.loc[gt_ts.index]

# %%
df_tot = pd.concat([df, gt_ts], axis=1)

# %% [markdown]
# Make a dataframe with all the keywords and the ground truth.

# %%
names = list(df.columns.values)
names.append('GroundTruth')
df_tot.columns = names
df_tot
# Out:
#          Amantadina  Antivirale  Artralgia  Cefalea  \
# 2011-42         162         178        391     1526
# 2011-43         183         210        385     1696
# 2011-44         224         279        449     2074
# 2011-45         221         248        466     2306
# 2011-46         290         245        464     2009
# 2011-47         252         297        437     2200
# 2011-48         243         280        462     2037
# 2011-49         185         230        439     1880
# 2011-50         252         295        425     1937
# 2011-51         124         150        213      902
# 2011-52         156         202        285     1317
# 2012-01         236         307        455     1861
# 2012-02         335         329        478     2062
# 2012-03         313         282        455     1864
# 2012-04         300         296        539     2102
# 2012-05         312         342        532     1995
# 2012-06         347         381        607     1963
# 2012-07         327         366        564     1918
# 2012-08         315         340        716     2079
# 2012-09         236         309        538     2134
# 2012-10         245         259        543     1652
# 2012-11         178         278        579     1974
# 2012-12         166         255        516     1767
# 2012-13         178         291        625     1750
# 2012-14         213         244        514     1632
# 2012-15         198         267        544     1751
# 2012-16         220         275        617     1900
# 2012-17         184         274        676     1686
# 2012-42         228         337        591     2483
# 2012-43         244         272        586     2599
# ...             ...         ...        ...      ...
# 2015-16         154         172        527      954
# 2015-17         151         207        367      987
# 2015-42          99         150        299      663
# 2015-43         123         115        208      684
# 2015-44         127         105        253      648
# 2015-45         119         117        249      744
# 2015-46         156         107        222      718
# 2015-47         137         242        199      635
# 2015-48         145         117        218      687
# 2015-49         134         129        206      625
# 2015-50         133         111        202      636
# 2015-51         141         130        211      576
# 2015-52          65         110        132      395
# 2015-53         107         106        168      517
# 2016-01         128         126        226      591
# 2016-02         157         160        271      670
# 2016-03         194         164        266      744
# 2016-04         185         158        310      795
# 2016-05         177         165        312      871
# 2016-06         188         178        278      827
# 2016-07         222         163        297      806
# 2016-08         165         181        309      761
# 2016-09         136         154        269      774
# 2016-10         129         170        259      804
# 2016-11         155         136        263      717
# 2016-12         125         157        202      665
# 2016-13         118         127        249      652
# 2016-14         106         152        249      708
# 2016-15         105         132        261      723
# 2016-16         136         164        258      615
#
#          Centro_europeo_per_la_prevenzione_e_il_controllo_delle_malattie  \
# 2011-42                                                 51
# 2011-43                                                 34
# 2011-44                                                 27
# 2011-45                                                 24
# 2011-46                                                 39
# 2011-47                                                 32
# 2011-48                                                 27
# 2011-49                                                 22
# 2011-50                                                 26
# 2011-51                                                 16
# 2011-52                                                 18
# 2012-01                                                 27
# 2012-02                                                 24
# 2012-03                                                 23
# 2012-04                                                 26
# 2012-05                                                 24
# 2012-06                                                 24
# 2012-07                                                 22
# 2012-08                                                 25
# 2012-09                                                 27
# 2012-10                                                 27
# 2012-11                                                 22
# 2012-12                                                 24
# 2012-13                                                 23
# 2012-14                                                 27
# 2012-15                                                 58
# 2012-16                                                 27
# 2012-17                                                 24
# 2012-42                                                 18
# 2012-43                                                 25
# ...                                                    ...
# 2015-16                                                 73
# 2015-17                                                 57
# 2015-42                                                 28
# 2015-43                                                 19
# 2015-44                                                 14
# 2015-45                                                 27
# 2015-46                                                 17
# 2015-47                                                 14
# 2015-48                                                 23
# 2015-49                                                 17
# 2015-50                                                 25
# 2015-51                                                 23
# 2015-52                                                 17
# 2015-53                                                 18
# 2016-01                                                 45
# 2016-02                                                 23
# 2016-03                                                 17
# 2016-04                                                 20
# 2016-05                                                 19
# 2016-06                                                 25
# 2016-07                                                 17
# 2016-08                                                 16
# 2016-09                                                 28
# 2016-10                                                 17
# 2016-11                                                 27
# 2016-12                                                 19
# 2016-13                                                 19
# 2016-14                                                 26
# 2016-15                                                 29
# 2016-16                                                 25
#
#          Epidemia  Febbre  Fotofobia  Influenza  Influenza_aviaria  \
# 2011-42       378    3499        433       1176                276
# 2011-43       413    3696        463       1119                354
# 2011-44       433    3962        527       1309                298
# 2011-45       425    4158        616       1352                343
# 2011-46       450    4139        508       1420                371
# 2011-47       440    4367        576       1558                414
# 2011-48       552    4403        506       1534               1470
# 2011-49       439    4161        469       1387                478
# 2011-50       422    4339        499       1463                438
# 2011-51       234    2471        268        833                747
# 2011-52       263    4882        375       1588                604
# 2012-01       535    5952        528       2037                466
# 2012-02       513    5885        645       2083                525
# 2012-03       463    6320        487       2092                527
# 2012-04       550    6978        536       2507                527
# 2012-05       506    7657        483       2728                519
# 2012-06       505    7196        568       2282                492
# 2012-07       509    6971        551       2198                483
# 2012-08       495    7253        596       2237                446
# 2012-09       422    5741        556       1664                430
# 2012-10       398    5100        552       1161                458
# 2012-11       538    4163        624       1198                435
# 2012-12       418    3828        553        938                356
# 2012-13       426    3295        580       1019                368
# 2012-14       415    3116        480        782                372
# 2012-15       468    3283        547        811                385
# 2012-16       460    3952        588        872                390
# 2012-17       503    3737        505        728                358
# 2012-42       462    4226        595       1587                633
# 2012-43       468    4192        588       1606                589
# ...           ...     ...        ...        ...                ...
# 2015-16       328    1168        317        579                303
# 2015-17       311    1089        349        560                273
# 2015-42       194     892        204        530                175
# 2015-43       229     895        204        507                183
# 2015-44       220     825        200        479                300
# 2015-45       274     847        200        576                198
# 2015-46       217     832        202        549                180
# 2015-47       210     909        236        532                181
# 2015-48       214     957        212        570                215
# 2015-49       187     924        175        563                307
# 2015-50       165     970        177        525                197
# 2015-51       167     881        163        580                137
# 2015-52        96     661        145        422                 91
# 2015-53       157     899        139        525                227
# 2016-01       199    1155        187        660                197
# 2016-02       244    1133        244        753                297
# 2016-03       264    1086        219        751                212
# 2016-04       291    1284        230        702                264
# 2016-05       290    1510        219        793                260
# 2016-06       348    1367        297        804                248
# 2016-07       784    1421        275        776                298
# 2016-08       467    1421        214        778                241
# 2016-09       255    1282        251        676                263
# 2016-10       247    1309        248        691                226
# 2016-11       207    1267        227        757                222
# 2016-12       179    1078        169        637                158
# 2016-13       250    1042        221        777                241
# 2016-14       213     940        222        544                218
# 2016-15       237     936        212        465                190
# 2016-16       182     793        229        467                196
#
#             ...       Paracetamolo  Raffreddore_comune  Rinorrea  Starnuto  \
# 2011-42     ...               4485                1898       363       454
# 2011-43     ...               4848                1747       352       454
# 2011-44     ...               4973                1783       333       498
# 2011-45     ...               4787                1545       369       483
# 2011-46     ...               4935                1789       374       513
# 2011-47     ...               6523                1830       375       564
# 2011-48     ...               5040                1831       404       498
# 2011-49     ...               4729                1566       367       498
# 2011-50     ...               4900                1533       366       518
# 2011-51     ...               3477                1141       168       285
# 2011-52     ...               5972                1861       278       423
# 2012-01     ...               6817                2352       425       643
# 2012-02     ...               6363                2087       409       632
# 2012-03     ...               6256                1865       375       565
# 2012-04     ...               6208                2266       433       584
# 2012-05     ...               6953                2229       434       619
# 2012-06     ...               7028                2136       412       620
# 2012-07     ...               6464                2142       390       580
# 2012-08     ...               6043                2116       814       688
# 2012-09     ...               5430                1893       408       664
# 2012-10     ...               7008                1753       393       603
# 2012-11     ...               4183                1564       424       521
# 2012-12     ...               3471                1320       400       489
# 2012-13     ...               3626                1246       429       528
# 2012-14     ...               3246                 961       344       502
# 2012-15     ...               3743                1106       364       448
# 2012-16     ...               3817                1074       345       414
# 2012-17     ...               4075                 991       399       458
# 2012-42     ...               5797                1868       401       705
# 2012-43     ...               5735                2309       359       738
# ...         ...                ...                 ...       ...       ...
# 2015-16     ...               2073                 617       242       307
# 2015-17     ...               1843                 612       208       308
# 2015-42     ...               1995                 922       197       211
# 2015-43     ...               1879                 787       147       186
# 2015-44     ...               1805                 607       137       182
# 2015-45     ...               1881                 606       163       182
# 2015-46     ...               1728                 523       148       186
# 2015-47     ...               1880                 480       163       156
# 2015-48     ...               1791                 586       153       197
# 2015-49     ...               2335                 604       144       184
# 2015-50     ...               2056                 575       186       214
# 2015-51     ...               1923                 648       174       269
# 2015-52     ...               1673                 554       122       158
# 2015-53     ...               1942                 788       169       182
# 2016-01     ...               2154                 936       226       242
# 2016-02     ...               2191                 771       212       218
# 2016-03     ...               2083                 805       185       269
# 2016-04     ...               2295                 852       229       287
# 2016-05     ...               2313                 820       240       267
# 2016-06     ...               2420                 751       218       268
# 2016-07     ...               2215                 688       200       297
# 2016-08     ...               2291                 657       200       276
# 2016-09     ...               2079                 575       187       227
# 2016-10     ...               2020                 497       194       221
# 2016-11     ...               2024                 519       172       197
# 2016-12     ...               1723                 411       196       207
# 2016-13     ...               1661                 598       179       220
# 2016-14     ...               1879                 427       183       192
# 2016-15     ...               1572                 415       149       208
# 2016-16     ...               1515                 424       181       232
#
#          Tosse  totalViews  Vaccino_antinfluenzale  Vomito  Zanamivir  \
# 2011-42   1663    93271823                     0.0    1724         68
# 2011-43   1947    99364715                     0.0    1825         67
# 2011-44   2211   108841801                     0.0    2173         62
# 2011-45   2268   109836162                   394.0    2118         55
# 2011-46   2140   106748952                   826.0    2110         67
# 2011-47   2277   105517950                  1129.0    2276         59
# 2011-48   2179   103806835                   761.0    2437         78
# 2011-49   2051   101174357                   453.0    2152         94
# 2011-50   1935   104067037                   345.0    2093         69
# 2011-51   1120    55305462                   147.0    1188         35
# 2011-52   1935    90211318                   160.0    2477         62
# 2012-01   2649   119823036                   179.0    2726         73
# 2012-02   2782   116279474                   197.0    2759         94
# 2012-03   2596   109904116                   187.0    2506         84
# 2012-04   2787   115702289                   199.0    2354        144
# 2012-05   2783   116246769                   238.0    2338        179
# 2012-06   2595   119656983                   190.0    2278        145
# 2012-07   2471   113809247                   188.0    2611        128
# 2012-08   2345   112860742                   174.0    2644        121
# 2012-09   2115   112172874                   169.0    2599         73
# 2012-10   2088   107815827                   120.0    2501         72
# 2012-11   1748   101505308                   134.0    2068         78
# 2012-12   1280    99418248                    90.0    1806         56
# 2012-13   1042    99082137                    80.0    1677         69
# 2012-14    990    97879780                    76.0    1650         47
# 2012-15   1013   107373915                    80.0    1978         54
# 2012-16   1026   106949016                    94.0    2063         62
# 2012-17   1011   102745188                    82.0    1942         53
# 2012-42   1283   121540632                   750.0    1986         68
# 2012-43   1402   122132429                  1061.0    2021         68
# ...        ...         ...                     ...     ...        ...
# 2015-16    505    79865047                    82.0     667         46
# 2015-17    370    80843535                   100.0     695         51
# 2015-42    348    52542024                   291.0     445         21
# 2015-43    345    49880045                   316.0     416         18
# 2015-44    388    49865506                   273.0     423         23
# 2015-45    360    52650244                   358.0     442         31
# 2015-46    409    53722960                   383.0     485         38
# 2015-47    339    55196890                   413.0     448         35
# 2015-48    308    53103330                   328.0     441         29
# 2015-49    328    51818693                   251.0     429         22
# 2015-50    323    50784272                   156.0     434         69
# 2015-51    326    49134283                   110.0     397         39
# 2015-52    286    41918624                    85.0     298         20
# 2015-53    336    48141667                    62.0     477         32
# 2016-01    395    59225424                    83.0     484         32
# 2016-02    476    60808188                    85.0     555         37
# 2016-03    411    59441516                    95.0     481         40
# 2016-04    388    58728254                    85.0     541         47
# 2016-05    403    59952557                    94.0     530         48
# 2016-06    429    60372242                    77.0     492         41
# 2016-07    443    59536013                    79.0     506         42
# 2016-08    416    57084524                    67.0     473         29
# 2016-09    378    59638966                    40.0     440         30
# 2016-10    391    56797538                    52.0     478         32
# 2016-11    352    56949096                    46.0     441         43
# 2016-12    290    56824960                    48.0     372         26
# 2016-13    272    58237823                    75.0     403         23
# 2016-14    273    53090047                    60.0     394         43
# 2016-15    316    50953039                    41.0     358         28
# 2016-16    256    53964932                    50.0     386         25
#
#          GroundTruth
# 2011-42         0.47
# 2011-43         0.54
# 2011-44         0.53
# 2011-45         0.72
# 2011-46         0.89
# 2011-47         1.14
# 2011-48         1.29
# 2011-49         1.36
# 2011-50         1.76
# 2011-51         2.20
# 2011-52         3.07
# 2012-01         3.13
# 2012-02         4.24
# 2012-03         6.30
# 2012-04         8.86
# 2012-05         9.64
# 2012-06         8.87
# 2012-07         7.14
# 2012-08         5.75
# 2012-09         4.03
# 2012-10         2.95
# 2012-11         2.13
# 2012-12         1.49
# 2012-13         1.13
# 2012-14         0.85
# 2012-15         0.84
# 2012-16         0.68
# 2012-17         0.46
# 2012-42         0.34
# 2012-43         0.46
# ...              ...
# 2015-16         1.15
# 2015-17         0.75
# 2015-42         0.40
# 2015-43         0.50
# 2015-44         0.68
# 2015-45         0.76
# 2015-46         0.88
# 2015-47         1.02
# 2015-48         1.16
# 2015-49         1.21
# 2015-50         1.45
# 2015-51         1.66
# 2015-52         2.11
# 2015-53         1.87
# 2016-01         2.39
# 2016-02         2.76
# 2016-03         3.62
# 2016-04         4.73
# 2016-05         5.47
# 2016-06         6.06
# 2016-07         5.90
# 2016-08         6.14
# 2016-09         5.88
# 2016-10         5.83
# 2016-11         5.00
# 2016-12         4.23
# 2016-13         3.18
# 2016-14         2.30
# 2016-15         1.85
# 2016-16         1.19
#
# [140 rows x 26 columns]

# %% [markdown]
# If we consider only the views is a good idea, but a better idea is to divide the views by the total views. This is done because the series could be affected by a trend of an increase use of wikipedia (to consult).

# %%
df_norm = df.divide(df['totalViews'], axis='index')

# %%
del df_norm['totalViews']
df_norm
# Out:
#          Amantadina  Antivirale  Artralgia   Cefalea  \
# 2011-42    0.000002    0.000002   0.000004  0.000016
# 2011-43    0.000002    0.000002   0.000004  0.000017
# 2011-44    0.000002    0.000003   0.000004  0.000019
# 2011-45    0.000002    0.000002   0.000004  0.000021
# 2011-46    0.000003    0.000002   0.000004  0.000019
# 2011-47    0.000002    0.000003   0.000004  0.000021
# 2011-48    0.000002    0.000003   0.000004  0.000020
# 2011-49    0.000002    0.000002   0.000004  0.000019
# 2011-50    0.000002    0.000003   0.000004  0.000019
# 2011-51    0.000002    0.000003   0.000004  0.000016
# 2011-52    0.000002    0.000002   0.000003  0.000015
# 2012-01    0.000002    0.000003   0.000004  0.000016
# 2012-02    0.000003    0.000003   0.000004  0.000018
# 2012-03    0.000003    0.000003   0.000004  0.000017
# 2012-04    0.000003    0.000003   0.000005  0.000018
# 2012-05    0.000003    0.000003   0.000005  0.000017
# 2012-06    0.000003    0.000003   0.000005  0.000016
# 2012-07    0.000003    0.000003   0.000005  0.000017
# 2012-08    0.000003    0.000003   0.000006  0.000018
# 2012-09    0.000002    0.000003   0.000005  0.000019
# 2012-10    0.000002    0.000002   0.000005  0.000015
# 2012-11    0.000002    0.000003   0.000006  0.000019
# 2012-12    0.000002    0.000003   0.000005  0.000018
# 2012-13    0.000002    0.000003   0.000006  0.000018
# 2012-14    0.000002    0.000002   0.000005  0.000017
# 2012-15    0.000002    0.000002   0.000005  0.000016
# 2012-16    0.000002    0.000003   0.000006  0.000018
# 2012-17    0.000002    0.000003   0.000007  0.000016
# 2012-42    0.000002    0.000003   0.000005  0.000020
# 2012-43    0.000002    0.000002   0.000005  0.000021
# ...             ...         ...        ...       ...
# 2015-16    0.000002    0.000002   0.000007  0.000012
# 2015-17    0.000002    0.000003   0.000005  0.000012
# 2015-42    0.000002    0.000003   0.000006  0.000013
# 2015-43    0.000002    0.000002   0.000004  0.000014
# 2015-44    0.000003    0.000002   0.000005  0.000013
# 2015-45    0.000002    0.000002   0.000005  0.000014
# 2015-46    0.000003    0.000002   0.000004  0.000013
# 2015-47    0.000002    0.000004   0.000004  0.000012
# 2015-48    0.000003    0.000002   0.000004  0.000013
# 2015-49    0.000003    0.000002   0.000004  0.000012
# 2015-50    0.000003    0.000002   0.000004  0.000013
# 2015-51    0.000003    0.000003   0.000004  0.000012
# 2015-52    0.000002    0.000003   0.000003  0.000009
# 2015-53    0.000002    0.000002   0.000003  0.000011
# 2016-01    0.000002    0.000002   0.000004  0.000010
# 2016-02    0.000003    0.000003   0.000004  0.000011
# 2016-03    0.000003    0.000003   0.000004  0.000013
# 2016-04    0.000003    0.000003   0.000005  0.000014
# 2016-05    0.000003    0.000003   0.000005  0.000015
# 2016-06    0.000003    0.000003   0.000005  0.000014
# 2016-07    0.000004    0.000003   0.000005  0.000014
# 2016-08    0.000003    0.000003   0.000005  0.000013
# 2016-09    0.000002    0.000003   0.000005  0.000013
# 2016-10    0.000002    0.000003   0.000005  0.000014
# 2016-11    0.000003    0.000002   0.000005  0.000013
# 2016-12    0.000002    0.000003   0.000004  0.000012
# 2016-13    0.000002    0.000002   0.000004  0.000011
# 2016-14    0.000002    0.000003   0.000005  0.000013
# 2016-15    0.000002    0.000003   0.000005  0.000014
# 2016-16    0.000003    0.000003   0.000005  0.000011
#
#          Centro_europeo_per_la_prevenzione_e_il_controllo_delle_malattie  \
# 2011-42                                       5.467889e-07
# 2011-43                                       3.421738e-07
# 2011-44                                       2.480665e-07
# 2011-45                                       2.185073e-07
# 2011-46                                       3.653432e-07
# 2011-47                                       3.032659e-07
# 2011-48                                       2.600985e-07
# 2011-49                                       2.174464e-07
# 2011-50                                       2.498390e-07
# 2011-51                                       2.893023e-07
# 2011-52                                       1.995315e-07
# 2012-01                                       2.253323e-07
# 2012-02                                       2.063993e-07
# 2012-03                                       2.092733e-07
# 2012-04                                       2.247147e-07
# 2012-05                                       2.064574e-07
# 2012-06                                       2.005733e-07
# 2012-07                                       1.933059e-07
# 2012-08                                       2.215119e-07
# 2012-09                                       2.406999e-07
# 2012-10                                       2.504271e-07
# 2012-11                                       2.167374e-07
# 2012-12                                       2.414044e-07
# 2012-13                                       2.321306e-07
# 2012-14                                       2.758486e-07
# 2012-15                                       5.401684e-07
# 2012-16                                       2.524567e-07
# 2012-17                                       2.335876e-07
# 2012-42                                       1.480986e-07
# 2012-43                                       2.046958e-07
# ...                                                    ...
# 2015-16                                       9.140419e-07
# 2015-17                                       7.050657e-07
# 2015-42                                       5.329068e-07
# 2015-43                                       3.809139e-07
# 2015-44                                       2.807552e-07
# 2015-45                                       5.128181e-07
# 2015-46                                       3.164383e-07
# 2015-47                                       2.536375e-07
# 2015-48                                       4.331178e-07
# 2015-49                                       3.280669e-07
# 2015-50                                       4.922784e-07
# 2015-51                                       4.681049e-07
# 2015-52                                       4.055477e-07
# 2015-53                                       3.738965e-07
# 2016-01                                       7.598088e-07
# 2016-02                                       3.782385e-07
# 2016-03                                       2.859954e-07
# 2016-04                                       3.405516e-07
# 2016-05                                       3.169173e-07
# 2016-06                                       4.140976e-07
# 2016-07                                       2.855415e-07
# 2016-08                                       2.802861e-07
# 2016-09                                       4.694917e-07
# 2016-10                                       2.993087e-07
# 2016-11                                       4.741076e-07
# 2016-12                                       3.343601e-07
# 2016-13                                       3.262485e-07
# 2016-14                                       4.897340e-07
# 2016-15                                       5.691515e-07
# 2016-16                                       4.632638e-07
#
#          Epidemia    Febbre  Fotofobia  Influenza  Influenza_aviaria  \
# 2011-42  0.000004  0.000038   0.000005   0.000013           0.000003
# 2011-43  0.000004  0.000037   0.000005   0.000011           0.000004
# 2011-44  0.000004  0.000036   0.000005   0.000012           0.000003
# 2011-45  0.000004  0.000038   0.000006   0.000012           0.000003
# 2011-46  0.000004  0.000039   0.000005   0.000013           0.000003
# 2011-47  0.000004  0.000041   0.000005   0.000015           0.000004
# 2011-48  0.000005  0.000042   0.000005   0.000015           0.000014
# 2011-49  0.000004  0.000041   0.000005   0.000014           0.000005
# 2011-50  0.000004  0.000042   0.000005   0.000014           0.000004
# 2011-51  0.000004  0.000045   0.000005   0.000015           0.000014
# 2011-52  0.000003  0.000054   0.000004   0.000018           0.000007
# 2012-01  0.000004  0.000050   0.000004   0.000017           0.000004
# 2012-02  0.000004  0.000051   0.000006   0.000018           0.000005
# 2012-03  0.000004  0.000058   0.000004   0.000019           0.000005
# 2012-04  0.000005  0.000060   0.000005   0.000022           0.000005
# 2012-05  0.000004  0.000066   0.000004   0.000023           0.000004
# 2012-06  0.000004  0.000060   0.000005   0.000019           0.000004
# 2012-07  0.000004  0.000061   0.000005   0.000019           0.000004
# 2012-08  0.000004  0.000064   0.000005   0.000020           0.000004
# 2012-09  0.000004  0.000051   0.000005   0.000015           0.000004
# 2012-10  0.000004  0.000047   0.000005   0.000011           0.000004
# 2012-11  0.000005  0.000041   0.000006   0.000012           0.000004
# 2012-12  0.000004  0.000039   0.000006   0.000009           0.000004
# 2012-13  0.000004  0.000033   0.000006   0.000010           0.000004
# 2012-14  0.000004  0.000032   0.000005   0.000008           0.000004
# 2012-15  0.000004  0.000031   0.000005   0.000008           0.000004
# 2012-16  0.000004  0.000037   0.000005   0.000008           0.000004
# 2012-17  0.000005  0.000036   0.000005   0.000007           0.000003
# 2012-42  0.000004  0.000035   0.000005   0.000013           0.000005
# 2012-43  0.000004  0.000034   0.000005   0.000013           0.000005
# ...           ...       ...        ...        ...                ...
# 2015-16  0.000004  0.000015   0.000004   0.000007           0.000004
# 2015-17  0.000004  0.000013   0.000004   0.000007           0.000003
# 2015-42  0.000004  0.000017   0.000004   0.000010           0.000003
# 2015-43  0.000005  0.000018   0.000004   0.000010           0.000004
# 2015-44  0.000004  0.000017   0.000004   0.000010           0.000006
# 2015-45  0.000005  0.000016   0.000004   0.000011           0.000004
# 2015-46  0.000004  0.000015   0.000004   0.000010           0.000003
# 2015-47  0.000004  0.000016   0.000004   0.000010           0.000003
# 2015-48  0.000004  0.000018   0.000004   0.000011           0.000004
# 2015-49  0.000004  0.000018   0.000003   0.000011           0.000006
# 2015-50  0.000003  0.000019   0.000003   0.000010           0.000004
# 2015-51  0.000003  0.000018   0.000003   0.000012           0.000003
# 2015-52  0.000002  0.000016   0.000003   0.000010           0.000002
# 2015-53  0.000003  0.000019   0.000003   0.000011           0.000005
# 2016-01  0.000003  0.000020   0.000003   0.000011           0.000003
# 2016-02  0.000004  0.000019   0.000004   0.000012           0.000005
# 2016-03  0.000004  0.000018   0.000004   0.000013           0.000004
# 2016-04  0.000005  0.000022   0.000004   0.000012           0.000004
# 2016-05  0.000005  0.000025   0.000004   0.000013           0.000004
# 2016-06  0.000006  0.000023   0.000005   0.000013           0.000004
# 2016-07  0.000013  0.000024   0.000005   0.000013           0.000005
# 2016-08  0.000008  0.000025   0.000004   0.000014           0.000004
# 2016-09  0.000004  0.000021   0.000004   0.000011           0.000004
# 2016-10  0.000004  0.000023   0.000004   0.000012           0.000004
# 2016-11  0.000004  0.000022   0.000004   0.000013           0.000004
# 2016-12  0.000003  0.000019   0.000003   0.000011           0.000003
# 2016-13  0.000004  0.000018   0.000004   0.000013           0.000004
# 2016-14  0.000004  0.000018   0.000004   0.000010           0.000004
# 2016-15  0.000005  0.000018   0.000004   0.000009           0.000004
# 2016-16  0.000003  0.000015   0.000004   0.000009           0.000004
#
#              ...        Oseltamivir  Pandemia_influenzale  Paracetamolo  \
# 2011-42      ...       1.072135e-06          1.211513e-06      0.000048
# 2011-43      ...       1.177480e-06          8.353066e-07      0.000049
# 2011-44      ...       1.093330e-06          9.187647e-07      0.000046
# 2011-45      ...       1.083432e-06          8.467157e-07      0.000044
# 2011-46      ...       1.152236e-06          8.712029e-07      0.000046
# 2011-47      ...       1.298357e-06          1.108816e-06      0.000062
# 2011-48      ...       1.165627e-06          1.165627e-06      0.000049
# 2011-49      ...       1.591312e-06          9.093213e-07      0.000047
# 2011-50      ...       1.201149e-06          1.028183e-06      0.000047
# 2011-51      ...       1.464593e-06          1.265698e-06      0.000063
# 2011-52      ...       1.241529e-06          9.200619e-07      0.000066
# 2012-01      ...       1.293574e-06          1.168390e-06      0.000057
# 2012-02      ...       1.496395e-06          9.115968e-07      0.000055
# 2012-03      ...       2.211018e-06          1.046367e-06      0.000057
# 2012-04      ...       2.229861e-06          1.279145e-06      0.000054
# 2012-05      ...       2.511898e-06          1.281756e-06      0.000060
# 2012-06      ...       2.189592e-06          1.195083e-06      0.000059
# 2012-07      ...       1.941846e-06          8.523033e-07      0.000057
# 2012-08      ...       1.745514e-06          9.746525e-07      0.000054
# 2012-09      ...       1.283733e-06          1.043033e-06      0.000048
# 2012-10      ...       9.553328e-07          1.085184e-06      0.000065
# 2012-11      ...       1.073835e-06          3.901274e-06      0.000041
# 2012-12      ...       1.015910e-06          1.287490e-06      0.000035
# 2012-13      ...       1.049634e-06          1.009264e-06      0.000037
# 2012-14      ...       9.501452e-07          7.764627e-07      0.000033
# 2012-15      ...       6.984937e-07          1.043084e-06      0.000035
# 2012-16      ...       1.000477e-06          1.047228e-06      0.000036
# 2012-17      ...       7.396940e-07          1.109541e-06      0.000040
# 2012-42      ...       1.201244e-06          1.522125e-06      0.000048
# 2012-43      ...       1.179048e-06          1.195424e-06      0.000047
# ...          ...                ...                   ...           ...
# 2015-16      ...       1.014211e-06          7.512673e-07      0.000026
# 2015-17      ...       7.174352e-07          7.545439e-07      0.000023
# 2015-42      ...       9.896840e-07          8.183925e-07      0.000038
# 2015-43      ...       6.014429e-07          9.623087e-07      0.000038
# 2015-44      ...       8.422656e-07          1.283452e-06      0.000036
# 2015-45      ...       9.496632e-07          1.139596e-06      0.000036
# 2015-46      ...       7.817886e-07          1.079613e-06      0.000032
# 2015-47      ...       8.877312e-07          7.609124e-07      0.000034
# 2015-48      ...       8.850669e-07          1.280522e-06      0.000034
# 2015-49      ...       8.491144e-07          9.263067e-07      0.000045
# 2015-50      ...       1.004248e-06          9.254834e-07      0.000040
# 2015-51      ...       1.058324e-06          1.383962e-06      0.000039
# 2015-52      ...       1.025797e-06          1.001941e-06      0.000040
# 2015-53      ...       1.246322e-06          1.204778e-06      0.000040
# 2016-01      ...       1.029963e-06          1.080617e-06      0.000036
# 2016-02      ...       1.233387e-06          1.068935e-06      0.000036
# 2016-03      ...       2.035614e-06          1.160805e-06      0.000035
# 2016-04      ...       2.366834e-06          1.396261e-06      0.000039
# 2016-05      ...       1.851464e-06          1.317709e-06      0.000039
# 2016-06      ...       1.457624e-06          1.639826e-06      0.000040
# 2016-07      ...       2.032383e-06          1.142166e-06      0.000037
# 2016-08      ...       1.804342e-06          1.453984e-06      0.000040
# 2016-09      ...       1.425243e-06          2.079178e-06      0.000035
# 2016-10      ...       1.725427e-06          1.144416e-06      0.000036
# 2016-11      ...       1.334525e-06          9.833343e-07      0.000036
# 2016-12      ...       1.143864e-06          8.974929e-07      0.000030
# 2016-13      ...       9.615744e-07          7.211808e-07      0.000029
# 2016-14      ...       1.299679e-06          9.606320e-07      0.000035
# 2016-15      ...       6.084034e-07          7.457848e-07      0.000031
# 2016-16      ...       5.559166e-07          1.074772e-06      0.000028
#
#          Raffreddore_comune  Rinorrea  Starnuto     Tosse  \
# 2011-42            0.000020  0.000004  0.000005  0.000018
# 2011-43            0.000018  0.000004  0.000005  0.000020
# 2011-44            0.000016  0.000003  0.000005  0.000020
# 2011-45            0.000014  0.000003  0.000004  0.000021
# 2011-46            0.000017  0.000004  0.000005  0.000020
# 2011-47            0.000017  0.000004  0.000005  0.000022
# 2011-48            0.000018  0.000004  0.000005  0.000021
# 2011-49            0.000015  0.000004  0.000005  0.000020
# 2011-50            0.000015  0.000004  0.000005  0.000019
# 2011-51            0.000021  0.000003  0.000005  0.000020
# 2011-52            0.000021  0.000003  0.000005  0.000021
# 2012-01            0.000020  0.000004  0.000005  0.000022
# 2012-02            0.000018  0.000004  0.000005  0.000024
# 2012-03            0.000017  0.000003  0.000005  0.000024
# 2012-04            0.000020  0.000004  0.000005  0.000024
# 2012-05            0.000019  0.000004  0.000005  0.000024
# 2012-06            0.000018  0.000003  0.000005  0.000022
# 2012-07            0.000019  0.000003  0.000005  0.000022
# 2012-08            0.000019  0.000007  0.000006  0.000021
# 2012-09            0.000017  0.000004  0.000006  0.000019
# 2012-10            0.000016  0.000004  0.000006  0.000019
# 2012-11            0.000015  0.000004  0.000005  0.000017
# 2012-12            0.000013  0.000004  0.000005  0.000013
# 2012-13            0.000013  0.000004  0.000005  0.000011
# 2012-14            0.000010  0.000004  0.000005  0.000010
# 2012-15            0.000010  0.000003  0.000004  0.000009
# 2012-16            0.000010  0.000003  0.000004  0.000010
# 2012-17            0.000010  0.000004  0.000004  0.000010
# 2012-42            0.000015  0.000003  0.000006  0.000011
# 2012-43            0.000019  0.000003  0.000006  0.000011
# ...                     ...       ...       ...       ...
# 2015-16            0.000008  0.000003  0.000004  0.000006
# 2015-17            0.000008  0.000003  0.000004  0.000005
# 2015-42            0.000018  0.000004  0.000004  0.000007
# 2015-43            0.000016  0.000003  0.000004  0.000007
# 2015-44            0.000012  0.000003  0.000004  0.000008
# 2015-45            0.000012  0.000003  0.000003  0.000007
# 2015-46            0.000010  0.000003  0.000003  0.000008
# 2015-47            0.000009  0.000003  0.000003  0.000006
# 2015-48            0.000011  0.000003  0.000004  0.000006
# 2015-49            0.000012  0.000003  0.000004  0.000006
# 2015-50            0.000011  0.000004  0.000004  0.000006
# 2015-51            0.000013  0.000004  0.000005  0.000007
# 2015-52            0.000013  0.000003  0.000004  0.000007
# 2015-53            0.000016  0.000004  0.000004  0.000007
# 2016-01            0.000016  0.000004  0.000004  0.000007
# 2016-02            0.000013  0.000003  0.000004  0.000008
# 2016-03            0.000014  0.000003  0.000005  0.000007
# 2016-04            0.000015  0.000004  0.000005  0.000007
# 2016-05            0.000014  0.000004  0.000004  0.000007
# 2016-06            0.000012  0.000004  0.000004  0.000007
# 2016-07            0.000012  0.000003  0.000005  0.000007
# 2016-08            0.000012  0.000004  0.000005  0.000007
# 2016-09            0.000010  0.000003  0.000004  0.000006
# 2016-10            0.000009  0.000003  0.000004  0.000007
# 2016-11            0.000009  0.000003  0.000003  0.000006
# 2016-12            0.000007  0.000003  0.000004  0.000005
# 2016-13            0.000010  0.000003  0.000004  0.000005
# 2016-14            0.000008  0.000003  0.000004  0.000005
# 2016-15            0.000008  0.000003  0.000004  0.000006
# 2016-16            0.000008  0.000003  0.000004  0.000005
#
#          Vaccino_antinfluenzale    Vomito     Zanamivir
# 2011-42            0.000000e+00  0.000018  7.290519e-07
# 2011-43            0.000000e+00  0.000018  6.742836e-07
# 2011-44            0.000000e+00  0.000020  5.696341e-07
# 2011-45            3.587161e-06  0.000019  5.007458e-07
# 2011-46            7.737781e-06  0.000020  6.276408e-07
# 2011-47            1.069960e-05  0.000022  5.591466e-07
# 2011-48            7.330924e-06  0.000023  7.513956e-07
# 2011-49            4.477419e-06  0.000021  9.290892e-07
# 2011-50            3.315171e-06  0.000020  6.630342e-07
# 2011-51            2.657965e-06  0.000021  6.328489e-07
# 2011-52            1.773613e-06  0.000027  6.872752e-07
# 2012-01            1.493870e-06  0.000023  6.092318e-07
# 2012-02            1.694194e-06  0.000024  8.083972e-07
# 2012-03            1.701483e-06  0.000023  7.643026e-07
# 2012-04            1.719931e-06  0.000020  1.244573e-06
# 2012-05            2.047369e-06  0.000020  1.539828e-06
# 2012-06            1.587872e-06  0.000019  1.211797e-06
# 2012-07            1.651887e-06  0.000023  1.124689e-06
# 2012-08            1.541723e-06  0.000023  1.072118e-06
# 2012-09            1.506603e-06  0.000023  6.507812e-07
# 2012-10            1.113009e-06  0.000023  6.678055e-07
# 2012-11            1.320128e-06  0.000020  7.684327e-07
# 2012-12            9.052664e-07  0.000018  5.632769e-07
# 2012-13            8.074109e-07  0.000017  6.963919e-07
# 2012-14            7.764627e-07  0.000017  4.801809e-07
# 2012-15            7.450599e-07  0.000018  5.029154e-07
# 2012-16            8.789235e-07  0.000019  5.797155e-07
# 2012-17            7.980909e-07  0.000019  5.158392e-07
# 2012-42            6.170776e-06  0.000016  5.594837e-07
# 2012-43            8.687291e-06  0.000017  5.567727e-07
# ...                         ...       ...           ...
# 2015-16            1.026732e-06  0.000008  5.759716e-07
# 2015-17            1.236957e-06  0.000009  6.308482e-07
# 2015-42            5.538424e-06  0.000008  3.996801e-07
# 2015-43            6.335199e-06  0.000008  3.608658e-07
# 2015-44            5.474726e-06  0.000008  4.612407e-07
# 2015-45            6.799589e-06  0.000008  5.887912e-07
# 2015-46            7.129168e-06  0.000009  7.073326e-07
# 2015-47            7.482306e-06  0.000008  6.340937e-07
# 2015-48            6.176637e-06  0.000008  5.461051e-07
# 2015-49            4.843812e-06  0.000008  4.245572e-07
# 2015-50            3.071817e-06  0.000009  1.358688e-06
# 2015-51            2.238763e-06  0.000008  7.937431e-07
# 2015-52            2.027738e-06  0.000007  4.771149e-07
# 2015-53            1.287866e-06  0.000010  6.647049e-07
# 2016-01            1.401425e-06  0.000008  5.403085e-07
# 2016-02            1.397838e-06  0.000009  6.084707e-07
# 2016-03            1.598210e-06  0.000008  6.729303e-07
# 2016-04            1.447344e-06  0.000009  8.002962e-07
# 2016-05            1.567906e-06  0.000009  8.006331e-07
# 2016-06            1.275421e-06  0.000008  6.791200e-07
# 2016-07            1.326928e-06  0.000008  7.054554e-07
# 2016-08            1.173698e-06  0.000008  5.080186e-07
# 2016-09            6.707024e-07  0.000007  5.030268e-07
# 2016-10            9.155326e-07  0.000008  5.634047e-07
# 2016-11            8.077389e-07  0.000008  7.550603e-07
# 2016-12            8.446992e-07  0.000007  4.575454e-07
# 2016-13            1.287823e-06  0.000007  3.949323e-07
# 2016-14            1.130155e-06  0.000007  8.099447e-07
# 2016-15            8.046625e-07  0.000007  5.495256e-07
# 2016-16            9.265276e-07  0.000007  4.632638e-07
#
# [140 rows x 24 columns]

# %% [markdown]
# Below a plot of the difference between the absolute value and relative value of Influenza time series. (note that the series are plotted with different axes)

# %%
df['Influenza'].plot(legend=True, label='Flu', color='r')
plt.title('"Influenza" Wikipedia Page View Data ['+ min(gt_ts.index)+' - '+max(gt_ts.index)+']', fontsize=14)
plt.xlabel('Year-Week')
plt.ylabel('Number of page views')
df_norm['Influenza'].plot(legend=True, label='Flu / TotalViews', secondary_y=True, color='g')
plt.ylabel('Percentage of influenza page views over total views')
plt.grid()
plt.show()

# %% [markdown]
# After that we consider all the page views normalized by the total views.

# %% [markdown]
# ## Part 1.2
#
# ### Compare the time series from the official Influnet surveillance system with the time series of "Influenza" pageviews

# %%
df_norm['Influenza'].plot(legend=True, label='Flu Weekly / TotalViews', color='g')
plt.title('"Influenza" Wikipedia Page View Data ['+ min(gt_ts.index)+' - '+max(gt_ts.index)+']', fontsize=14)
plt.xlabel('Year-Week')
plt.ylabel('Percentage of influenza page views over total views')
gt_ts.plot(legend=True, label='Ground Truth', secondary_y=True, color='b')
plt.ylabel('Estimated flu incidence')
plt.grid()
plt.show()

# %% [markdown]
# It's evident a similar evolution of the wikipedia click on page "Influenza" respect to ground truth, but to have an objective indicator we try to compute the correlation between the two time series.

# %% [markdown]
# Initially I have consider some measures of correlation:
#  - Pearson Correlation
#  - Cross Correlation
#  - Spearman rank-order Correlation

# %% [markdown]
# Let's start to analyze them:

# %% [markdown]
# #### Pearson correlation

# %% [markdown]
# The Pearson correlation coefficient measures the linear relationship between two datasets. Strictly speaking, Pearson’s correlation requires that each dataset be normally distributed, and not necessarily zero-mean. Like other correlation coefficients, this one varies between -1 and +1 with 0 implying no correlation. Correlations of -1 or +1 imply an exact linear relationship. Positive correlations imply that as x increases, so does y. Negative correlations imply that as x increases, y decreases.
# The p-value roughly indicates the probability of an uncorrelated system producing datasets that have a Pearson correlation at least as extreme as the one computed from these datasets.
#
# To apply this measure of correlation we try to verify if they are normally distributed, and to do that we use Jarque-Bera test and normal test.

# %% [markdown]
# **Jarque-Bera test** work for a large enough number of data sample (>2000) and the test asymptoticcaly has a Chi-Squared distribution with 2 degrees of freedom.
#
# The null hypothesis **H0** is a joint hypothesis of the *skewness being zero* and the *excess kurtosis being zero* (kurtosis equal to 3, excess kurtosis equal to 0)

# %%
jb_value,p = scipy.stats.jarque_bera(gt_ts)
print 'Ground Truth - Statistic test', round(jb_value,4), 'with', p, 'p-value'
# Out:
# Ground Truth - Statistic test 26.8481 with 1.47912398418e-06 p-value

# %%
jb_value,p = scipy.stats.jarque_bera(df_norm['Influenza'])
print 'Influenza - Statistic test', round(jb_value,4), 'with', p, 'p-value'
# Out:
# Influenza - Statistic test 74.3368 with 1.11022302463e-16 p-value

# %% [markdown]
# **Normal test** is based on D’Agostino and Pearson’s test that combines skew and kurtosis to produce an omnibus test of normality.
#
# Obviously the null hypothesis **H0** is normal distribution and the test is distributed as a Chi-Square.

# %%
k2,p = scipy.stats.mstats.normaltest(gt_ts)
print 'Ground Truth - Statistic test', round(k2,4), 'with', p, 'p-value'
# Out:
# Ground Truth - Statistic test 21.2782 with 2.39607991243e-05 p-value

# %%
k2,p = scipy.stats.mstats.normaltest(df_norm['Influenza'])
print 'Influenza - Statistic test', round(k2,4), 'with', p, 'p-value'
# Out:
# Influenza - Statistic test 40.3316 with 1.74624418387e-09 p-value

# %% [markdown]
# Both the test Reject the null hypothesis of normal distribution, the correlation measure haven't any sense. Only to play I have tried to do the measure of Pearson correlation

# %%
coeff, pvalue = pearsonr(gt_ts, df_norm['Influenza'])
print coeff, ' ', pvalue
# Out:
# 0.750461057133   1.36011511074e-26

# %% [markdown]
# #### Cross-correlation

# %% [markdown]
# Relationships between time series is by the cross-correlation function (assuming stationarity). To use this measure we should verify the stationarity of the two series. The null hypothesis is of zero correlation .
#
# To do that I have used the Augmented Dickey-Fuller test. The null hypothesis of the Augmented Dickey-Fuller is that there is a unit root, with the alternative that there is no unit root. If the pvalue is above a critical size, then we cannot reject that there is a unit root.
#
# The p-values are obtained through regression surface approximation from MacKinnon 1994, but using the updated 2010 tables. If the p-value is close to significant, then the critical values should be used to judge whether to accept or reject the null.

# %%
adf,pvalue,_,_,_,_ = statsmodels.tsa.stattools.adfuller(gt_ts)
print 'Augmented Dickey-Fuller unit root test - Ground Truth Series'
print 'Test statistic:', round(adf,4), 'with', pvalue, "p-value"
# Out:
# Augmented Dickey-Fuller unit root test - Ground Truth Series
# Test statistic: -5.6384 with 1.05025106912e-06 p-value

# %%
adf,pvalue,_,_,_,_ = statsmodels.tsa.stattools.adfuller(df_norm['Influenza'])
print 'Augmented Dickey-Fuller unit root test - Influenza Series'
print 'Test statistic:', round(adf,4), 'with', pvalue, "p-value"
# Out:
# Augmented Dickey-Fuller unit root test - Influenza Series
# Test statistic: -4.4052 with 0.000290597006878 p-value

# %% [markdown]
# For each series we reject the null hypothesis of unit root at level 5% and also 1%. We assume stationarity!
# This will be the measure of correlation that we use in this assignment.

# %% [markdown]
# The function of numpy.correlate and scipy.signal.correlate return an incorrect value of correlation. To solve this I have written the function correctly (I hope).

# %% [markdown]
# The function, given two time series in input, return the correlation value, the statistic test and the p-value.

# %%
def crossCorr(x,y):
    num = np.mean((x-np.mean(x))*(y-np.mean(y)))
    den = np.std(x)*np.std(y)
    r = num/den
    
    #significance
    n = len(x)
    t = r * ((n-2)/(1-r**2))**(0.5)
    pvalue = 1-scipy.stats.t.cdf(t, n-2)        
    
    return r,t,pvalue

# %%
r,t,p = crossCorr(gt_ts, df_norm['Influenza'])

print 'The correlation between Ground Truth and Influenza is:'
print 'Cross-Correlation',round(r,4), 'with statistic test', round(t,4), 'and pvalue', p
# Out:
# The correlation between Ground Truth and Influenza is:
# Cross-Correlation 0.7505 with statistic test 13.339 and pvalue 0.0

# %% [markdown]
# The null hypothesis $H_0$ of zero correlation is rejected at every level $\alpha$

# %% [markdown]
# #### Spearman rank-order correlation

# %% [markdown]
# The Spearman's rank-order correlation is the nonparametric version of the Pearson product-moment correlation. Spearman's correlation coefficient measures the strength and direction of association between two ranked variables and this is not our case!

# %% [markdown]
# *Note*: The measure of correlation that I have used in all of the next point is **Cross-Correlation**

# %% [markdown]
# ## Part 2.1
#
# ### Try to find other Wikipedia pages related to flu whose pageview time series	are correlated with the Influnet signal

# %% [markdown]
# The choose of the keywords and then of the pageviews is done in this way:
#  - keywords used in the paper (mentioned at the beginning)
#  - keywords mentioned in the assignment text
#  - keywords linked in the Influenza Wikipedia web page
#
# The last point is interesting, because the page with an high correlation with Influenza is a strong evidence of people interested to symptom, evolution and drugs of Influenza. They are searching exactly this things!

# %% [markdown]
# We repeat the same analyze done for only Influenza serie, to all the dataframe.

# %% [markdown]
# A briefly view of the keywords series

# %%
pos = [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1]]
fig, axes = plt.subplots(nrows=3, ncols=2,sharey=True,sharex=True,figsize=(20,20))
for i in range(int(np.ceil(float(len(df_norm.columns))/4))):
    a,b = pos[i]
    gt_ts.plot(ax=axes[a,b], legend=True, label='Ground Truth', secondary_y=True, color='b')
    df_norm[df_norm.columns[(i*4)]].plot(ax=axes[a,b], legend=True, label=df_norm.columns[(i*4)], color='g')
    df_norm[df_norm.columns[(i*4)+1]].plot(ax=axes[a,b], legend=True, label=df_norm.columns[(i*4)+1], color='m')
    df_norm[df_norm.columns[(i*4)+2]].plot(ax=axes[a,b], legend=True, label=df_norm.columns[(i*4)+2], color='c')
    df_norm[df_norm.columns[(i*4)+3]].plot(ax=axes[a,b], legend=True, label=df_norm.columns[(i*4)+3], color='r')
plt.show()

# %% [markdown]
# Fever seem to have a correlation with ground truth (plot 0,1), Influenza_A_sottotipo_H1N1 (plot 1,0) like Influenza (plot 1,0) analyzed above.
# A strange things appear in the last plot (plot 2,1): the keywords Vaccino_antinfluenzale seem to anticipate the flu season and have an evolution similar than ground truth.
#
# At this point we continue without any treatment of the series.

# %% [markdown]
# ## Part 2.2
#
# ### On aggregating the hourly pageview data to compute weekly pageviews, can you do something to select page views from Italy?

# %% [markdown]
# Given this question some consideration are acceptable like do a random samples or we can see how the views are distributed during the 24-hours. I'm interesting to follow the second option.
#
# To do that I have defined a function call *hourly*, this function reload all the data but it aggregated the views by the hour. Every basic treatment of the series explained before are done.

# %%
def hourly(filename, sep):
    ts = pd.Series.from_csv(filename, sep = sep, header=None, index_col = 0)
    wts = ts.groupby(ts.index.strftime('%H')).mean()
    return wts

# %%
df_h = pd.concat([hourly(f, ' ') for f in glob.glob(path + "/*.txt")], axis=1)
df_h = df_h.fillna(0)

# %%
df_h.columns = [os.path.basename(f).split('.')[0] for f in glob.glob(path + "/*.txt")]

# %%
df_h["Influenzavirus_A_sottotipo_H1N1"] = df_h["Influenzavirus_A_sottotipo_H1N1"].add(df_h["Virus_dell'influenza_A_sottotipo_H1N1"], fill_value=0).add(df_h["Virus_dell%27influenza_A_sottotipo_H1N1"], fill_value=0)

# %%
del df_h["Virus_dell'influenza_A_sottotipo_H1N1"]
del df_h["Virus_dell%27influenza_A_sottotipo_H1N1"]

# %%
df_h_tot = df_h.copy()

# %%
del df_h['totalViews']

# %% [markdown]
# A plot will help us to understand the distribution of the views by hour. Except some keywords drop to zero, the series with a consistent number of visualizations follow the same trend

# %%
ax = df_h.plot(legend=True)
plt.title('Distribution of page view in a ordinary day')
plt.xlabel('Hour of the day')
plt.ylabel('Number of visualization for each page downloaded')
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid()
plt.show()

# %% [markdown]
# Below a summarize plot.

# %%
df_h_tot.mean(axis=1).plot(marker='o', linestyle='-', legend=True, label='Page Views')
plt.xlabel('Hour of the day')
plt.ylabel('Number of visualization every day for each hour')
plt.title('Distribution of page view in a ordinary day')
df_h.mean(axis=1).plot(marker='o', linestyle='-', secondary_y=True, legend=True, label='Average')
plt.ylabel('Number of visualization for each page downloaded')
df_h.quantile(q=0.75, axis=1).plot(marker='o', linestyle='-', secondary_y=True, legend=True, label='3rd Quartile')
df_h.quantile(q=0.50, axis=1).plot(marker='o', linestyle='-', secondary_y=True, legend=True, label='2nd Quartile - Median')
df_h.quantile(q=0.25, axis=1).plot(marker='o', linestyle='-', secondary_y=True, legend=True, label='1st Quartile')
plt.grid()
plt.show()

# %% [markdown]
# In this plot is evident that if we would select a subset of the views without loss of information, we can drop the night hours (e.g. between 0-8 or 1-7 or 2-5 depend how accuracy we would have).

# %% [markdown]
# ## Part 2.3
#
# ### For each of the selected Wikipedia pages, compute the same correlation	with the Influnet time series

# %% [markdown]
# With the function of the *Cross-Correlation* defined before, we compute the measure of correlation between the selected pages and the groud truth

# %%
corr = [crossCorr(gt_ts, df_norm[i])[0] for i in list(df_norm.columns)]

# %%
for i in range(len(df_norm.columns)):
    print('\t'.join(['%.4f','%.33s']) % (corr[i], df_norm.columns[i]))
# Out:
# 0.4122	Amantadina
# 0.5480	Antivirale
# 0.0950	Artralgia
# -0.0691	Cefalea
# 0.0243	Centro_europeo_per_la_prevenzione
# 0.2914	Epidemia
# 0.4608	Febbre
# 0.0817	Fotofobia
# 0.7505	Influenza
# 0.1926	Influenza_aviaria
# 0.5817	Influenzavirus_A
# 0.6136	Influenzavirus_A_sottotipo_H1N1
# -0.0446	Istituto_superiore_di_sanità
# 0.0968	Mialgia
# 0.6305	Oseltamivir
# 0.1581	Pandemia_influenzale
# 0.4129	Paracetamolo
# 0.2639	Raffreddore_comune
# 0.3497	Rinorrea
# 0.2502	Starnuto
# 0.2611	Tosse
# -0.3684	Vaccino_antinfluenzale
# 0.0754	Vomito
# 0.6276	Zanamivir

# %% [markdown]
# Is easy to understand if we sort in descending order the correlation.
# Pay attention that a negative correlation but with high negative value is significant as positive! (abs use to do that)

# %%
id_sort = sorted(range(len(corr)), reverse=True, key = np.abs(corr).__getitem__)
print 'Correlation of selected wikipedia pages in descending order'
for i in range(len(df_norm.columns)):
    print('\t'.join(['%.4f','%.33s']) % (corr[id_sort[i]], df_norm.columns[id_sort[i]]))
# Out:
# Correlation of selected wikipedia pages in descending order
# 0.7505	Influenza
# 0.6305	Oseltamivir
# 0.6276	Zanamivir
# 0.6136	Influenzavirus_A_sottotipo_H1N1
# 0.5817	Influenzavirus_A
# 0.5480	Antivirale
# 0.4608	Febbre
# 0.4129	Paracetamolo
# 0.4122	Amantadina
# -0.3684	Vaccino_antinfluenzale
# 0.3497	Rinorrea
# 0.2914	Epidemia
# 0.2639	Raffreddore_comune
# 0.2611	Tosse
# 0.2502	Starnuto
# 0.1926	Influenza_aviaria
# 0.1581	Pandemia_influenzale
# 0.0968	Mialgia
# 0.0950	Artralgia
# 0.0817	Fotofobia
# 0.0754	Vomito
# -0.0691	Cefalea
# -0.0446	Istituto_superiore_di_sanità
# 0.0243	Centro_europeo_per_la_prevenzione

# %% [markdown]
# Influenza is again the page views more correlated with the ground truth.

# %% [markdown]
# ## Part 3.1
#
# ### Build a regression model that predicts the Influnet incidence for a given week based on the Wikipedia pageview data for the same week.

# %% [markdown]
# We should select some feature from the 24-involved. We build a score for each feature given by a mean of four indicator:
#  - F-test
#  - Mutual Information
#  - Cross-Correlation (explained before)

# %% [markdown]
# **F-test** [f_regression function]
#
# The methods based on F-test estimate the degree of linear dependency between two random variables. It is a univariate linear regression tests.
# Quick linear model for testing the effect of a single regressor, sequentially for many regressors.
#
# This is done in 2 steps:
#  - The cross correlation between each regressor and the target is computed, that is,
#
#  ((X[:, i] - mean(X[:, i])) * (y - mean_y)) / (std(X[:, i]) * std(y))
#
#
#  - It is converted to an F score then to a p-value.

# %% [markdown]
# **Mutual Information** [mutal_info_regression]
#
# The mutual information methods can capture any kind of statistical dependency, but being nonparametric, they require more samples for accurate estimation.
# It estimate mutual information for a continuous target variable.
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. It is equal to zero if and only if two random variables are independent, and higher values mean higher dependency.
# The function relies on nonparametric methods based on entropy estimation from k-nearest neighbors distances.

# %%
# F-test
f_test, _ = f_regression(df_norm,gt_ts)
f_test = normalize([f_test])[0]

# Mutual Information
mi = mutual_info_regression(df_norm,gt_ts)
mi = normalize([mi])[0]

# Cross-Correlation
corr = [crossCorr(gt_ts, df_norm[i])[0] for i in list(df_norm.columns)]
corr = normalize([ccorr])[0]

# Score
score = np.mean([f_test,mi,corr,ccorr], axis=0)

# %%
sort_index_f_test = sorted(range(len(f_test)), key=np.abs(f_test).__getitem__, reverse=True)
sort_index_mi = sorted(range(len(mi)), key=np.abs(mi).__getitem__, reverse=True)
sort_index_corr = sorted(range(len(corr)), key=np.abs(corr).__getitem__, reverse=True)
sort_index_score = sorted(range(len(score)), key=np.abs(score).__getitem__, reverse=True)

# %%
# Select the top k elements
k = 5

# %%
f_test_col = ['\033[36m%.4f\033[0m' if i  in sort_index_f_test[0:5] else '\033[30m%.4f' for i in range(len(df_norm.columns))]
mi_col     = ['\033[36m%.4f\033[0m' if i in sort_index_mi[0:k] else '\033[30m%.4f' for i in range(len(df_norm.columns))]
corr_col   = ['\033[36m%.4f\033[0m' if i in sort_index_corr[0:k] else '\033[30m%.4f' for i in range(len(df_norm.columns))]
score_col  = ['\033[36m%.4f\033[0m' if i in sort_index_score[0:k] else '\033[30m%.4f' for i in range(len(df_norm.columns))]
feat_col   = ['\033[46m%s\033[0m' if i in sort_index_score[0:k] else '\033[30m%s' for i in range(len(df_norm.columns))]

# %%
print ('\t'.join(['f_reg', 'mi', 'corr', 'score', 'feature']))
for i in range(len(df_norm.columns)):
    print('\t'.join([f_test_col[i], mi_col[i], corr_col[i], score_col[i], feat_col[i]]) % (f_test[i], f_test[i], corr[i], score[i], df_norm.columns[i][:33]))
# Out:
# f_reg	mi	corr	score	feature
# 0.1085	0.1085	0.2183	0.1674	Amantadina
# 0.2276	0.2276	0.2902	0.2442	Antivirale
# 0.0048	0.0048	0.0503	0.0491	Artralgia
# 0.0025	0.0025	-0.0366	-0.0129	Cefalea
# 0.0003	0.0003	0.0129	0.0120	Centro_europeo_per_la_prevenzione
# 0.0492	0.0492	0.1543	0.1070	Epidemia
# 0.1429	0.1429	0.2440	0.2571	Febbre
# 0.0036	0.0036	0.0433	0.0335	Fotofobia
# 0.6835	0.6835	0.3974	0.4580	Influenza
# 0.0204	0.0204	0.1020	0.0736	Influenza_aviaria
# 0.2712	0.2712	0.3081	0.2796	Influenzavirus_A
# 0.3202	0.3202	0.3250	0.3349	Influenzavirus_A_sottotipo_H1N1
# 0.0011	0.0011	-0.0236	0.0027	Istituto_superiore_di_sanità
# 0.0050	0.0050	0.0513	0.0306	Mialgia
# 0.3497	0.3497	0.3339	0.3632	Oseltamivir
# 0.0136	0.0136	0.0837	0.0566	Pandemia_influenzale
# 0.1089	0.1089	0.2186	0.1731	Paracetamolo
# 0.0397	0.0397	0.1397	0.0889	Raffreddore_comune
# 0.0739	0.0739	0.1852	0.1408	Rinorrea
# 0.0354	0.0354	0.1325	0.1106	Starnuto
# 0.0388	0.0388	0.1382	0.0910	Tosse
# 0.0832	0.0832	-0.1951	0.0166	Vaccino_antinfluenzale
# 0.0030	0.0030	0.0399	0.0515	Vomito
# 0.3446	0.3446	0.3324	0.3100	Zanamivir

# %%
print 'The top feature is', df_norm.columns[score.argmax()],'with score',  round(score.max(),4)
# Out:
# The top feature is Influenza with score 0.458

# %%
ind = np.argpartition(score, -k)[-k:]
ind = ind[np.argsort(score[ind], -1, )][::-1]

# %%
print 'The top', k, 'features are:'
for i in range(len(ind)):
    print (i+1), ' with value ', round(score[ind[i]],4),'is', df_norm.columns[ind[i]]
# Out:
# The top 5 features are:
# 1  with value  0.458 is Influenza
# 2  with value  0.3632 is Oseltamivir
# 3  with value  0.3349 is Influenzavirus_A_sottotipo_H1N1
# 4  with value  0.31 is Zanamivir
# 5  with value  0.2796 is Influenzavirus_A

# %%
top_corr = np.corrcoef(df_norm[list(df_norm.columns[ind])], rowvar=0)
print top_corr
# Out:
# [[ 1.          0.54288161  0.49994673  0.55222429  0.32382716]
#  [ 0.54288161  1.          0.5006891   0.62880622  0.51401772]
#  [ 0.49994673  0.5006891   1.          0.42860158  0.62360429]
#  [ 0.55222429  0.62880622  0.42860158  1.          0.51714339]
#  [ 0.32382716  0.51401772  0.62360429  0.51714339  1.        ]]

# %% [markdown]
# In the matrix above we can see a significant correlation between the feature selected.
#
# This is an interesting point of view of the features selection, because the top 5 features are highly correlated with the ground truth but also between their.
#
# As touched on before, correlation between the keywords selected is an indicator that the people are searching exactly this thing!

# %% [markdown]
# **Build a model - model 0**
#
# Try to build a model with the 5 top features.
# A briefly introduction of what we do in this model:
#  - No treatment are applied at the series
#  - No shift at each series
#  - No cut at night hours
#  - No dummy variables (for each season)
#  - No ARMA model
#
# This assumption imply that in the sequel this argument will be treated.
# Moreover in this first model with linear regression we point attention at the model, coefficient, coefficients significance, and relative p-value.

# %% [markdown]
# Create a dataframe with the selected features

# %%
df_top = df_norm[list(df_norm.columns[ind])].copy()

# %% [markdown]
# Split the dataset in train and test (70-30) and fit the model.

# %%
id_train, id_test = train_test_split(range(len(gt_ts.index)), train_size = 0.7, test_size = 0.3)

# %%
X_train = df_top.iloc[id_train]
X_test = df_top.iloc[id_test]
y_train = gt_ts.iloc[id_train]
y_test = gt_ts.iloc[id_test]

# %%
reg = linear_model.LinearRegression(fit_intercept=True, normalize=True).fit(X_train,y_train)

# %%
sse = np.sum((reg.predict(X_train) - y_train) ** 2, axis=0) / float(X_train.shape[0] - X_train.shape[1])
se = np.array([np.sqrt(np.diagonal(sse * np.linalg.inv(np.dot(X_train.T, X_train))))])
t = reg.coef_ / se
p = 2 * (1 - stats.t.cdf(np.abs(t), y_train.shape[0] - X_train.shape[1]))

# %%
# The intercept
print 'Intercept: \n', reg.intercept_
# Out:
# Intercept:
# -3.81967087621

# %%
print '\t'.join(['Coefficient','t-stat','p-value','feature'])
for i in range(len(df_top.columns)):
    print '\t'.join(['%.4f','%.4f','%.4f','%s']) % (reg.coef_[i],t[0][i],p[0][i],df_top.columns[i])
# Out:
# Coefficient	t-stat	p-value	feature
# 260074.7111	7.4080	0.0000	Influenza
# 296858.1170	0.8765	0.3830	Oseltamivir
# 4603.5826	0.0997	0.9208	Influenzavirus_A_sottotipo_H1N1
# 2240802.3837	2.7030	0.0082	Zanamivir
# 1431688.9945	3.9432	0.0002	Influenzavirus_A

# %%
# The mean squared error
print("Mean squared error: %.4f" % np.mean((reg.predict(X_test) - y_test) ** 2))
# Out:
# Mean squared error: 2.6349

# %%
# Returns the coefficient of determination R^2 of the prediction
# Explained variance score: 1 is perfect prediction
print 'Coefficient of determination R^2 of the prediction', reg.score(X_test, y_test)
# Out:
# Coefficient of determination R^2 of the prediction 0.594585880895

# %% [markdown]
# **Cross-validation - Multiple model performance**

# %% [markdown]
# Now it's time to evaluate the performance of three model with cross-validation.

# %% [markdown]
# *Generalized Linear Models*
#
# The methods involved for regression, the target value is expected to be a linear combination of the input variables.
#
# $\hat{y}(w, x) = w_0 + w_1 x_1 + ... + w_p x_p$
#
# $\hat{y}$ is the predicted value, the vector $w = (w_1,..., w_p)$ as _coef_ and $w_0$ as _intercept_.
#
# Model selected:
#  - *Ordinary Least Squares*: LinearRegression fits a linear model with coefficients $w = (w_1, ..., w_p)$ to minimize the residual sum of squares between the observed responses in the dataset, and the responses predicted by the linear approximation.
# $\underset{w}{min\,} {|| X w - y||_2}^2$
#
#
#  - *Ridge Regression*: Ridge regression addresses some of the problems of Ordinary Least Squares by imposing a penalty on the size of coefficients. The ridge coefficients minimize a penalized residual sum of squares, $\underset{w}{min\,} {{|| X w - y||_2}^2 + \alpha {||w||_2}^2}$<br>
# Here, $\alpha \geq 0$ is a complexity parameter that controls the amount of shrinkage: the larger the value of $\alpha$, the greater the amount of shrinkage and thus the coefficients become more robust to collinearity.
#
#
#  - *Lasso Regression*: The Lasso is a linear model that estimates sparse coefficients. It is useful in some contexts due to its tendency to prefer solutions with fewer parameter values, effectively reducing the number of variables upon which the given solution is dependent.
# It consists of a linear model trained with $\ell_1$ prior as regularizer. The objective function to minimize is:
# $\underset{w}{min\,} { \frac{1}{2n_{samples}} ||X w - y||_2 ^ 2 + \alpha ||w||_1}$
# The lasso estimate thus solves the minimization of the least-squares penalty with $\alpha ||w||_1$ added, where $\alpha$ is a constant and $||w||_1$ is the $\ell_1$-norm of the parameter vector.
#
#
#
#  - *Bayesian Regression*: Bayesian regression techniques can be used to include regularization parameters in the estimation procedure: the regularization parameter is not set in a hard sense but tuned to the data at hand. This can be done by introducing uninformative priors over the hyper parameters of the model. The $\ell_{2}$ regularization used in Ridge Regression is equivalent to finding a maximum a-postiori solution under a Gaussian prior over the parameters w with precision $\lambda^-1$. Instead of setting lambda manually, it is possible to treat it as a random variable to be estimated from the data. To obtain a fully probabilistic model, the output y is assumed to be Gaussian distributed around <br> $X_w$: $p(y|X,w,\alpha) = \mathcal{N}(y|X w,\alpha)$<br> Alpha is again treated as a random variable that is to be estimated from the data. The advantages of Bayesian Regression are:
#     - It adapts to the data at hand.
#     - It can be used to include regularization parameters in the estimation procedure.<br>
#
#   The disadvantages of Bayesian regression include:
#     - Inference of the model can be time consuming.
#
#
#  - *Polynomial regression*: One common pattern within machine learning is to use linear models trained on nonlinear functions of the data. This approach maintains the generally fast performance of linear methods, while allowing them to fit a much wider range of data.
# If we want to fit a paraboloid to the data instead of a plane, we can combine the features in second-order polynomials, so that the model looks like this:
# $\hat{y}(w, x) = w_0 + w_1 x_1 + w_2 x_2 + w_3 x_1 x_2 + w_4 x_1^2 + w_5 x_2^2$<br>
# The observation is that this is still a linear model: imagine creating a new variable
# $z = [x_1, x_2, x_1 x_2, x_1^2, x_2^2]$<br>
# With this re-labeling of the data, our problem can be written
# $\hat{y}(w, x) = w_0 + w_1 z_1 + w_2 z_2 + w_3 z_3 + w_4 z_4 + w_5 z_5$<br>
# We see that the resulting polynomial regression is in the same class of linear models we’d considered above (the model is linear in w) and can be solved by the same techniques. By considering linear fits within a higher-dimensional space built with these basis functions, the model has the flexibility to fit a much broader range of data.

# %%
kf = KFold(n_splits=10, shuffle=True).split(df_top.index)
models = ['LinearRegression','Ridge','Lasso','Bayesian','Polynomial']
mse = {m:[] for m in models}
alphas = [0.01,0.02,0.05,0.08,0.1,0.2,0.5,0.8,1,2,5,8]

# %%
for tr, te in kf:
    X_train = df_top.iloc[tr]
    X_test = df_top.iloc[te]
    y_train = gt_ts.iloc[tr]
    y_test = gt_ts.iloc[te]
    
    ### Ordinary least squares Linear Regression
    reg = linear_model.LinearRegression(fit_intercept=True, normalize=True).fit(X_train,y_train)
    mse['LinearRegression'].append(np.mean((reg.predict(X_test) - y_test) ** 2))
    
    ### Ridge Regression
    ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(X_train, y_train)
    ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(X_train, y_train)
    mse['Ridge'].append(np.mean((ridge.predict(X_test) - y_test) ** 2))
    
    ### Lasso Regression
    lasso_cv = linear_model.LassoCV(fit_intercept=True, normalize=True, alphas=alphas).fit(X_train, y_train)
    lasso = linear_model.Lasso(fit_intercept=True, normalize=True, alpha = round(lasso_cv.alpha_,3)).fit(X_train, y_train)
    mse['Lasso'].append(np.mean((lasso.predict(X_test) - y_test) ** 2))
    
    ### Bayesian Ridge Regression
    bay = linear_model.BayesianRidge(fit_intercept=True, normalize=True).fit(X_train, y_train)
    mse['Bayesian'].append(np.mean((bay.predict(X_test) - y_test) ** 2))
    
    ### Polynomial Regression
    pol = Pipeline([('poly', PolynomialFeatures(degree=2)),
                    ('linear', linear_model.LinearRegression(fit_intercept=True, normalize=True))]).fit(X_train, y_train)
    mse['Polynomial'].append(np.mean((pol.predict(X_test) - y_test) ** 2))

# %%
mse_mean = {k: np.mean(mse[k]) for k in models}
print 'MSE models means'
for k, v in mse_mean.iteritems():
    print round(v,5),'\t', k
print '\nThe model with the minimum MSE', min(mse_mean.values()),'is', min(mse_mean, key=mse_mean.get)
# Out:
# MSE models means
# 2.58173 	Bayesian
# 2.58149 	Ridge
# 10.48331 	Polynomial
# 2.59667 	LinearRegression
# 2.64418 	Lasso
#
# The model with the minimum MSE 2.58149332266 is Ridge

# %% [markdown]
# The first approach at the prediction with the Ridge model is an increase train set from one observation to all minus one obs to estimate the coefficients of the model and a prediction of one week out-of-sample.

# %%
y_pred = []
for i in range(1,len(df_top.index)):
    X_train = df_top.iloc[:i]
    X_test = df_top.iloc[[i]]
    y_train = gt_ts.iloc[:i]
    y_test = gt_ts.iloc[[i]]
    ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(X_train, y_train)
    ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(X_train, y_train)
    y_pred.append(ridge.predict(X_test)[0])

# %%
flu_pred_rol = pd.Series(y_pred, index=df_top.index[1:], name='flu_pred')

# %%
flu_pred_rol.plot(legend=True, label='Flu prediction incidence - Rolling window')
gt_ts[flu_pred_rol.index].plot(legend=True, label=('Ground Truth'))
plt.title('Prediction with Rolling Windows - one week out of sample')
plt.xlabel('Year-Week')
plt.ylabel('Flu incidence')
plt.grid()
plt.show()

# %% [markdown]
# The model with the lowest MSE is Ridge. After that we try with a rolling window of 10 and 28 weeks to predict the next 1 week and see how it performs.
# 0 is a random value, but 28 is equal to 1 season observation and in this way we see how it perform in the next year

# %%
windows = [10,28]
y_pred = {w:[] for w in windows}

# %%
for w in windows:
    for i in range(len(df_top.index)-w):
        X_train = df_top.iloc[i:i+w]
        X_test = df_top.iloc[[i+w]]
        y_train = gt_ts.iloc[i:i+w]
        y_test = gt_ts.iloc[[i+w]]
        ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(X_train, y_train)
        ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(X_train, y_train)
        y_pred[w].append(ridge.predict(X_test)[0])

# %%
flu_pred_rol = pd.concat([pd.Series(y_pred[w], index=df_top.index[w:], name=w) for w in windows], axis=1)
flu_pred_rol = pd.concat([gt_ts, flu_pred_rol], axis=1)
del flu_pred_rol[0]

# %%
gt_ts.plot(legend=True, label='Ground Truth')
plt.title('Prediction with Rolling Windows - one week out of sample')
plt.xlabel('Year-Week')
plt.ylabel('Flu incidence')
for w in windows:
    flu_pred_rol[w].plot(legend=True, label=('Flu prediction incidence - Rolling window '+ str(w)))
plt.grid()
plt.show()

# %% [markdown]
# The series are almost nearly. A fast measure of correlation:

# %%
r,t,p = crossCorr(gt_ts[flu_pred_rol[windows[1]].index], flu_pred_rol[windows[1]])
print 'The correlation between Ground Truth and Flu Prediction is:'
print 'Cross-Correlation',round(r,4), 'with statistic test', round(t,4), 'and pvalue', p
# Out:
# The correlation between Ground Truth and Flu Prediction is:
# Cross-Correlation 0.7664 with statistic test 14.0159 and pvalue 0.0

# %% [markdown]
# An other way to see how the model predict is to select one year, let the machine learning given this subset and after that try to estimate the flu of the next year. In the next cell this are done and at the end plot it.

# %%
y_pred = {i:[] for i in range(4)}
for i in range(4):
    X_train = df_top.iloc[i*28:(i+1)*28]
    X_test = df_top.iloc[(i+1)*28:(i+2)*28]
    y_train = gt_ts.iloc[i*28:(i+1)*28]
    y_test = gt_ts.iloc[(i+1)*28:(i+1)*28]
    ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(X_train, y_train)
    ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(X_train, y_train)
    y_pred[i].append(ridge.predict(X_test))

# %%
flu_pred_rol = pd.concat([pd.Series(y_pred[i][0], index=df_top.index[(i+1)*28:(i+2)*28], name=i+1) for i in range(4)], axis=1)
flu_pred_rol = pd.concat([gt_ts, flu_pred_rol], axis=1)
del flu_pred_rol[0]

# %%
gt_ts.plot(legend=True, label='Ground Truth')
plt.title('Prediction with Rolling Windows - one week out of sample')
plt.xlabel('Year-Week')
plt.ylabel('Flu incidence')
for i in range(4):
    flu_pred_rol[i+1].plot(legend=True, label=('Flu prediction incidence - Season '+ str(i+1)))
plt.grid()
plt.show()

# %% [markdown]
# Last prediction is done with all the previous season to let estimate the coeff and after that try to estimate the flu of the next year.<br>
# The difference with the prediction above are only in the period considered to estimate the parameter of the model.

# %%
y_pred = {i:[] for i in range(4)}
for i in range(4):
    X_train = df_top.iloc[:(i+1)*28]
    X_test = df_top.iloc[(i+1)*28:(i+2)*28]
    y_train = gt_ts.iloc[:(i+1)*28]
    y_test = gt_ts.iloc[(i+1)*28:(i+1)*28]
    ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(X_train, y_train)
    ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(X_train, y_train)
    y_pred[i].append(ridge.predict(X_test))

# %%
flu_pred_rol = pd.concat([pd.Series(y_pred[i][0], index=df_top.index[(i+1)*28:(i+2)*28], name=i+1) for i in range(4)], axis=1)
flu_pred_rol = pd.concat([gt_ts, flu_pred_rol], axis=1)
del flu_pred_rol[0]

# %% [markdown]
# gt_ts.plot(legend=True, label='Ground Truth')
# plt.title('Prediction with Rolling Windows - one week out of sample')
# plt.xlabel('Year-Week')
# plt.ylabel('Flu incidence')
# for i in range(4):
#     flu_pred_rol[i+1].plot(legend=True, label=('Flu prediction incidence - Season '+ str(i+1)))
# plt.grid()
# plt.show()

# %% [markdown]
# Not significant difference are observable.

# %% [markdown]
# No treatment are applied at the series
# No shift at each series
# No cut at night hours
# No dummy variables (for each season)
# No ARMA model

# %%
yr = sorted(list(set([int(x.split('-')[0]) for x in df_top.index.values])))

# %%
yr_id = [yr.index(int(x.split('-')[0])) if x.split('-')[1]<27 else (yr.index(int(x.split('-')[0]))+1) for x in df_top.index.values]

# %%
yr_dummies = pd.get_dummies(yr_id).astype(np.int8)
yr_dummies.set_index(gt_ts.index, inplace = True)
df_an = pd.concat([df_top,yr_dummies], axis=1)
df_an

# %%
id_train, id_test = train_test_split(range(len(gt_ts.index)), train_size = 0.7, test_size = 0.3)

# %%
X_train = df_an.iloc[id_train]
X_test = df_an.iloc[id_test]
y_train = gt_ts.iloc[id_train]
y_test = gt_ts.iloc[id_test]

# %%
reg = linear_model.LinearRegression(fit_intercept=True, normalize=True).fit(X_train,y_train)

# %%
sse = np.sum((reg.predict(X_train) - y_train) ** 2, axis=0) / float(X_train.shape[0] - X_train.shape[1])
se = np.array([np.sqrt(np.diagonal(sse * np.linalg.inv(np.dot(X_train.T, X_train))))])
t = reg.coef_ / se
p = 2 * (1 - stats.t.cdf(np.abs(t), y_train.shape[0] - X_train.shape[1]))

# %%
# The intercept
print 'Intercept: \n', reg.intercept_

# %%
# The coefficients
print 'Coefficients: \n', reg.coef_

# %%
# The t statistics
print 't statistics: \n', t

# %%
# The p-value
print 'p-value: \n', p

# %%
# The mean squared error
print("Mean squared error: %.4f" % np.mean((reg.predict(X_test) - y_test) ** 2))

# %%
# Returns the coefficient of determination R^2 of the prediction
# Explained variance score: 1 is perfect prediction
reg.score(X_test, y_test)

# %%
X_train = df_an.iloc[id_train]
X_test = df_an.iloc[id_test]
y_train = gt_ts.iloc[id_train]
y_test = gt_ts.iloc[id_test]

# %%
kf = KFold(n_splits=10, shuffle=True).split(df_an.index)
models = ['LinearRegression', 'Ridge', 'Lasso', 'Bayesian']
mse = {m:[] for m in models}
alphas = [0.01,0.02,0.05,0.08,0.1,0.2,0.5,0.8,1,2,5,8]

# %%
for tr, te in kf:
    X_train = df_an.iloc[tr]
    X_test = df_an.iloc[te]
    y_train = gt_ts.iloc[tr]
    y_test = gt_ts.iloc[te]
    
    ### Ordinary least squares Linear Regression
    reg = linear_model.LinearRegression(fit_intercept=True, normalize=True).fit(X_train,y_train)
    mse['LinearRegression'].append(np.mean((reg.predict(X_test) - y_test) ** 2))
    
    ### Ridge Regression
    ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(X_train, y_train)
    ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(X_train, y_train)
    mse['Ridge'].append(np.mean((ridge.predict(X_test) - y_test) ** 2))
    
    ### Lasso Regression
    lasso_cv = linear_model.LassoCV(fit_intercept=True, normalize=True, alphas=alphas).fit(X_train, y_train)
    lasso = linear_model.Lasso(fit_intercept=True, normalize=True, alpha = round(lasso_cv.alpha_,3)).fit(X_train, y_train)
    mse['Lasso'].append(np.mean((lasso.predict(X_test) - y_test) ** 2))
    
    ### Bayesian Ridge Regression
    bay = linear_model.BayesianRidge(fit_intercept=True, normalize=True).fit(X_train, y_train)
    mse['Bayesian'].append(np.mean((bay.predict(X_test) - y_test) ** 2))

# %%
mse_mean = {k: np.mean(mse[k]) for k in models}
print 'MSE models means'
for k, v in mse_mean.iteritems():
    print round(v,4), k
print '\nThe model with the minimum MSE', min(mse_mean.values()),'is', min(mse_mean, key=mse_mean.get)

# %% [markdown]
# ### Ridge Regression

# %%
ridge_cv = linear_model.RidgeCV(fit_intercept=True, normalize=True, alphas = alphas).fit(df_an[[-10,:]], gt_ts[[-10,:]])
ridge = linear_model.Ridge(fit_intercept=True, normalize=True, alpha = round(ridge_cv.alpha_,3)).fit(df_an[[-10,:]], gt_ts[[-10,:]])
#np.mean((ridge.predict(X_test) - y_test) ** 2)

# %%
# The mean squared error
print("Mean squared error: %.4f" % np.mean((reg.predict(X_test) - y_test) ** 2))

# %% [markdown]
# ### shift all variables  and autocorrelation

# %%
tsa = sm.tsa

# %%
df_arima = df_raw.copy()

df_arima_norm = df_arima.divide(df_arima['totalViews'], axis='index')
del df_arima_norm['totalViews']
df_arima_norm.fillna(0, inplace=True)

# %%
c_shift = {c:[] for c in df_arima_norm.columns}
c_s_idx = {c:[] for c in df_arima_norm.columns}
for c in df_arima_norm.columns:
    c_shift[c].append([pearsonr(gt_ts, df_arima_norm[c].shift(i)[gt_ts.index].fillna(0))[0] for i in range(20)])
    c_s_idx[c].append(c_shift[c][0].index(max(c_shift[c][0], key=abs)))
c_s_idx

# %%
for c in df_arima_norm.columns:
    df_arima_norm[c] = df_arima_norm[c].shift(c_s_idx[c][0])[gt_ts.index].fillna(0)
df_arima_norm = df_arima_norm.loc[gt_ts.index]
df_arima_norm

# %%
corr_arima = df_arima_norm.corrwith(gt_ts)

# %%
print(corr_arima.values)

# %%
print 'The highest correlation with the ground truth is given by', corr_arima.idxmax() , 'with value', max(corr_arima)

# %%
acf, ci, Q, pvalue = tsa.acf((reg.predict(X_test) - y_test), nlags=10,confint=95, qstat=True, unbiased=True)

# %%
acf

# %%
pvalue

# %%
plt.figure()
z = stats.norm.ppf(0.975)
n = len(y_test)
plt.bar(np.arange(len(acf)), acf, width=.1, linewidth=0, color='red')
plt.title('ACF ' + df_arima_norm.columns[i])
plt.xlabel('lag')
plt.axhline(y=z / np.sqrt(n), linestyle='-', color='blue')
plt.axhline(y=-z / np.sqrt(n), linestyle='-',linewidth=1, color='blue')
plt.axhline(y=0 / np.sqrt(n), linestyle=':', color='black')
plt.show()

# %%
k = 5

# %%
pos = [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1],[3,0],[3,1],[4,0],[4,1]]
fig, axes = plt.subplots(nrows=5, ncols=2,sharey=True,sharex=True,figsize=(20,20))
z = stats.norm.ppf(0.975)
for i in range(k):
    acf = statsmodels.tsa.stattools.acf(df_arima_norm[df_arima_norm.columns[i]], alpha=0.05)[0]
    pacf = statsmodels.tsa.stattools.pacf(df_arima_norm[df_arima_norm.columns[i]], alpha=0.05)[0]
    a,b = pos[i*2]
    n = len(df_arima_norm[df_arima_norm.columns[i]])
    axes[a,b].bar(np.arange(len(acf)), acf, width=.4, linewidth=0, color='red')
    axes[a,b].set_title('ACF ' + df_arima_norm.columns[i])
    axes[a,b].set_xlabel('lag')
    axes[a,b].axhline(y=z / np.sqrt(n), linestyle='-', color='blue')
    axes[a,b].axhline(y=-z / np.sqrt(n), linestyle='-',linewidth=1, color='blue')
    axes[a,b].axhline(y=0 / np.sqrt(n), linestyle=':', color='black')

    a,b = pos[(i*2)+1]
    axes[a,b].bar(np.arange(len(pacf)), pacf, width=.4, linewidth=0, color='red')
    axes[a,b].set_title('PACF ' + df_arima_norm.columns[i])
    axes[a,b].set_xlabel('lag')
    axes[a,b].axhline(y=z / np.sqrt(n), linestyle='-', color='blue')
    axes[a,b].axhline(y=-z / np.sqrt(n), linestyle='-', color='blue')
    axes[a,b].axhline(y=0 / np.sqrt(n), linestyle=':', color='black')
plt.show()

# %%
a=statsmodels.tsa.arima_model.ARIMA(df_arima_norm['Antivirale'].values, order=(2,0,0)).fit(trend='nc')

# %%
a.summary()

# %%
pos = [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1],[3,0],[3,1],[4,0],[4,1]]
fig, axes = plt.subplots(nrows=5, ncols=2,sharey=True,sharex=True,figsize=(20,20))
z = stats.norm.ppf(0.975)
for i in range(k):
    arima_treat=statsmodels.tsa.arima_model.ARIMA(df_arima_norm[df_arima_normpippo_norm.columns[i]].values, order=(1,0,1)).fit(trend='nc')
    acf = statsmodels.tsa.stattools.acf(df_arima_norm[df_arima_norm.columns[i]].values-arima_treat.predict(), alpha=0.05)[0]
    pacf = statsmodels.tsa.stattools.pacf(df_arima_norm[df_arima_norm.columns[i]].values-arima_treat.predict(), alpha=0.05)[0]
    a,b = pos[i*2]
    n = len(df_arima_norm[df_arima_norm.columns[i]])
    axes[a,b].bar(np.arange(len(acf)), acf, width=.4, linewidth=0, color='red')
    axes[a,b].set_title('ACF ' + df_arima_norm.columns[i])
    axes[a,b].set_xlabel('lag')
    axes[a,b].axhline(y=z / np.sqrt(n), linestyle='-', color='blue')
    axes[a,b].axhline(y=-z / np.sqrt(n), linestyle='-',linewidth=1, color='blue')
    axes[a,b].axhline(y=0 / np.sqrt(n), linestyle=':', color='black')

    a,b = pos[(i*2)+1]
    axes[a,b].bar(np.arange(len(pacf)), pacf, width=.4, linewidth=0, color='red')
    axes[a,b].set_title('PACF ' + df_arima_norm.columns[i])
    axes[a,b].set_xlabel('lag')
    axes[a,b].axhline(y=z / np.sqrt(n), linestyle='-', color='blue')
    axes[a,b].axhline(y=-z / np.sqrt(n), linestyle='-', color='blue')
    axes[a,b].axhline(y=0 / np.sqrt(n), linestyle=':', color='black')
plt.show()

# %%
gt_ts.plot(legend=True, label='Ground Truth', secondary_y=True, color='b')
df_norm['Vaccino_antinfluenzale'].plot(legend=True, label='Vaccino_antinfluenzale', color='g')
plt.title('Series Plot Ground Truth vs Vaccino_antinfluenzale')
plt.show()

# %%
va = hourlyToWeekly(path + 'Vaccino_antinfluenzale.txt', ' ')
tot = hourlyToWeekly(path + 'totalViews.txt', ' ')
va_norm = va/tot
va_norm.fillna(0, inplace=True)

# %% [markdown]
#  19:56, 7 nov 2011‎ Doc.mari (Discussione | contributi)‎ m . . (33 923 byte) (0)‎ . . (ha spostato Vaccino influenzale a Vaccino antinfluenzale: Come da discussione) (annulla)
#  https://it.wikipedia.org/w/index.php?title=Vaccino_antinfluenzale&offset=&limit=500&action=history

# %%
va_shift = [pearsonr(gt_ts, va_norm.shift(i)[gt_ts.index].fillna(0))[0] for i in range(20)]
vasi = va_shift.index(max(va_shift))

# %%
df['Vaccino_antinfluenzale'] = va.shift(vasi)[gt_ts.index]
df_tot['Vaccino_antinfluenzale'] = va.shift(vasi)[gt_ts.index]
df_norm['Vaccino_antinfluenzale'] = va_norm.shift(vasi)[gt_ts.index].fillna(0)

# %%
gt_ts.plot(legend=True, label='Ground Truth', secondary_y=True, color='b')
df_norm['Vaccino_antinfluenzale'].plot(legend=True, label='Vaccino_antinfluenzale', color='g')
plt.title('Series Plot after shift treatment')
plt.show()

# %%
df_arima = df_raw.copy()

df_arima_norm = df_arima.divide(df_arima['totalViews'], axis='index')
del df_arima_norm['totalViews']
df_arima_norm.fillna(0, inplace=True)

# %%
crossCorr(gt_ts, df_arima_norm[c].shift(i)[gt_ts.index].fillna(0))

# %%
c_shift = {c:[] for c in df_arima_norm.columns}
c_s_idx = {c:[] for c in df_arima_norm.columns}
for c in df_arima_norm.columns:
    c_shift[c].append([crossCorr(gt_ts, df_arima_norm[c].shift(i)[gt_ts.index].fillna(0)) for i in range(20)])
    c_s_idx[c].append(c_shift[c][0].index(max(c_shift[c][0], key=abs)))
c_s_idx

# %%
for c in df_arima_norm.columns:
    df_arima_norm[c] = df_arima_norm[c].shift(c_s_idx[c][0])[gt_ts.index].fillna(0)
df_arima_norm = df_arima_norm.loc[gt_ts.index]
df_arima_norm

# %%
c_shift = {c:[] for c in df_norm.columns}
for c in df_norm.columns:
    c_shift[c].append([np.correlate(gt_ts, (df_raw[c]/df_raw['totalViews']).shift(i)[gt_ts.index].fillna(0))[0] for i in range(140)])

# %%
for c in c_shift:
    plt.plot(range(len(c_shift[c][0])), c_shift[c][0], linestyle='-', marker='.')
plt.grid()
plt.show()

# %% [markdown]
# quelle che hanno un'alta correlazioen all'inizio continuano ad avere alta correlazione anche a ritardi seguenti
# Da considerare i riatardi pari ad una annualità, e di ritardo due come si vedrà da acf e pacf ARIMA(1,0,1)

# %%
shift = [np.correlate(gt_ts, (df_raw['Influenza']/df_raw['totalViews']).shift(i)[gt_ts.index].fillna(0)) for i in range(140)]

# %%
plt.plot(range(len(shift)),shift, color='blue', linestyle='-', marker='.', label='cross-correlation')
plt.title('Ground truth vs Influenza (with shift) Cross-Correlation')
plt.xlabel('lag')
plt.grid()
plt.show()

# %%
best_shift = shift.index(max(shift))

# %%
best_shift

# %%
va_shift = [pearsonr(gt_ts, va_norm.shift(i)[gt_ts.index].fillna(0))[0] for i in range(20)]
vasi = va_shift.index(max(va_shift))
